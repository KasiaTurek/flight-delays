# %% [markdown]
#  # Opis notatnika
#
#  W tym notatniku pobieram dane do obszaru roboczego, i wgrywam do bazy danych. Ich obróbka oraz analiza zostanie przeprowadzona w kolejnych notatnikach.
#
#  Korzystam z dedykowanego serwisu API, stworzonego przez szkołę CodersLab, który dostępny jest pod adresem: https://api-datalab.coderslab.com/api/v2.
#  Dodatkowo udostępniona została dokumentacja, z którą można zapoznać się tutaj: [klik](https://api-datalab.coderslab.com/v2/docs/).
#
#  > Dokumentacja jest czysto techniczna i ma na celu prezentację dostępnych endpointów wraz ze zwracanym typem. W celu przetestowania należy kliknąć przysisk `Authorize`, podać token (dostępny tylko dla kursantów CodersLab), a następnie `Try it out!` oraz uzupełnić wymagane pola (parametry requesta).
#
#  Zgodnie z dokumentacją udostępnione zostały 4 endpointy:
#  - `airport` - dane o lotnisku,
#  - `weather` - informacje o zarejestrowaniej pogodzie na lotnisku danego dnia,
#  - `aircraft` - dane o samolotach
#  - `flights` - dane o wylotach z danego lotniska per dzień.
#
#  W celu pobrania informacji, gdzie wymagany jest paramatr `airportId`, korzystam z pliku `airports.csv` z folderu `data`.

# %% [markdown]
#  # Konfiguracja notatnika

# %% [markdown]
#  Import wymaganych bibliotek

# %%
import requests
import pandas as pd
import time
import datetime
from dateutil.relativedelta import relativedelta

# %% [markdown]
#  Paramatry połączenia do API

# %%
headers = {'accept': 'application/json', 'authorization': '***'} # token udostępniony tylko dla kursantów

# %% [markdown]
#  Wczytanie pliku `airports.csv` aby pozyskać listę lotnisk (dostępna w kolumnie `origin_airport_id`).

# %%
airports = pd.read_csv(r"..\data\airports.csv")

airports_list = airports['origin_airport_id'].to_list()

len(airports_list)
# Out:
# 364

# %% [markdown]
#  # Pobieranie `Airport`

# %% [markdown]
#  Pobieram dane z endpoint'u `airport` do listy.

# %%
all_API_airports_in_list = []
total_processing_time = 0

for airportId in airports_list:
    start_time = time.time()
    response = requests.get(f'https://api-datalab.coderslab.com/api/v2/airport/{airportId}', headers=headers)
    try:
        if response.status_code == 200:
            data = response.json()
            all_API_airports_in_list.append(data)
            print(f"For airport ID : {airportId} API status code is {response.status_code}")
        else:
            print(f"Failed to fetch data for airport ID : {airportId}, API status code is {response.status_code}")
    except Exception as e:
        print(f"An error occurred while processing airport ID : {airportId}. Error message: {str(e)}")
        continue

    end_time = time.time()
    processing_time = end_time - start_time
    total_processing_time += processing_time

    time.sleep(1)

total_minutes = int(total_processing_time // 60)
total_seconds = int(total_processing_time % 60)

print("--------------------------------------------------------------------------")
print(f"Total processing time: {total_minutes} minutes and {total_seconds} seconds")
print("--------------------------------------------------------------------------")
# Out:
# Failed to fetch data for airport ID : 10874, API status code is 400
# Failed to fetch data for airport ID : 11233, API status code is 400
# Failed to fetch data for airport ID : 13360, API status code is 400
# Failed to fetch data for airport ID : 15008, API status code is 400
# For airport ID : 11638 API status code is 200
# Failed to fetch data for airport ID : 14150, API status code is 400
# Failed to fetch data for airport ID : 15323, API status code is 400
# Failed to fetch data for airport ID : 14814, API status code is 400
# Failed to fetch data for airport ID : 12007, API status code is 400
# Failed to fetch data for airport ID : 11337, API status code is 400
# For airport ID : 13342 API status code is 200
# Failed to fetch data for airport ID : 15070, API status code is 400
# For airport ID : 13244 API status code is 200
# Failed to fetch data for airport ID : 12280, API status code is 400
# For airport ID : 15096 API status code is 200
# Failed to fetch data for airport ID : 11641, API status code is 400
# Failed to fetch data for airport ID : 13832, API status code is 400
# Failed to fetch data for airport ID : 10268, API status code is 400
# For airport ID : 10397 API status code is 200
# Failed to fetch data for airport ID : 15041, API status code is 400
# For airport ID : 10529 API status code is 200
# Failed to fetch data for airport ID : 12119, API status code is 400
# Failed to fetch data for airport ID : 11537, API status code is 400
# Failed to fetch data for airport ID : 11092, API status code is 400
# Failed to fetch data for airport ID : 10581, API status code is 400
# Failed to fetch data for airport ID : 13829, API status code is 400
# Failed to fetch data for airport ID : 15389, API status code is 400
# For airport ID : 10140 API status code is 200
# Failed to fetch data for airport ID : 12389, API status code is 400
# Failed to fetch data for airport ID : 11648, API status code is 400
# Failed to fetch data for airport ID : 15023, API status code is 400
# Failed to fetch data for airport ID : 11982, API status code is 400
# Failed to fetch data for airport ID : 10967, API status code is 400
# Failed to fetch data for airport ID : 11525, API status code is 400
# For airport ID : 10792 API status code is 200
# Failed to fetch data for airport ID : 14259, API status code is 400
# Failed to fetch data for airport ID : 11637, API status code is 400
# Failed to fetch data for airport ID : 10466, API status code is 400
# For airport ID : 10599 API status code is 200
# Failed to fetch data for airport ID : 10208, API status code is 400
# Failed to fetch data for airport ID : 15841, API status code is 400
# For airport ID : 14831 API status code is 200
# Failed to fetch data for airport ID : 12898, API status code is 400
# Failed to fetch data for airport ID : 13241, API status code is 400
# Failed to fetch data for airport ID : 13367, API status code is 400
# Failed to fetch data for airport ID : 11481, API status code is 400
# Failed to fetch data for airport ID : 14108, API status code is 400
# For airport ID : 13931 API status code is 200
# Failed to fetch data for airport ID : 13873, API status code is 400
# Failed to fetch data for airport ID : 10157, API status code is 400
# Failed to fetch data for airport ID : 10245, API status code is 400
# Failed to fetch data for airport ID : 11146, API status code is 400
# Failed to fetch data for airport ID : 13277, API status code is 400
# For airport ID : 11292 API status code is 200
# Failed to fetch data for airport ID : 11109, API status code is 400
# Failed to fetch data for airport ID : 13459, API status code is 400
# Failed to fetch data for airport ID : 11775, API status code is 400
# Failed to fetch data for airport ID : 16218, API status code is 400
# Failed to fetch data for airport ID : 14698, API status code is 400
# Failed to fetch data for airport ID : 14252, API status code is 400
# Failed to fetch data for airport ID : 13256, API status code is 400
# Failed to fetch data for airport ID : 13139, API status code is 400
# Failed to fetch data for airport ID : 12250, API status code is 400
# For airport ID : 11259 API status code is 200
# Failed to fetch data for airport ID : 11468, API status code is 400
# Failed to fetch data for airport ID : 14952, API status code is 400
# Failed to fetch data for airport ID : 12402, API status code is 400
# Failed to fetch data for airport ID : 14574, API status code is 400
# For airport ID : 11996 API status code is 200
# Failed to fetch data for airport ID : 11977, API status code is 400
# Failed to fetch data for airport ID : 11867, API status code is 400
# Failed to fetch data for airport ID : 11203, API status code is 400
# For airport ID : 11995 API status code is 200
# For airport ID : 15016 API status code is 200
# Failed to fetch data for airport ID : 10747, API status code is 400
# Failed to fetch data for airport ID : 14905, API status code is 400
# Failed to fetch data for airport ID : 12012, API status code is 400
# Failed to fetch data for airport ID : 14783, API status code is 400
# For airport ID : 14730 API status code is 200
# Failed to fetch data for airport ID : 10431, API status code is 400
# Failed to fetch data for airport ID : 10434, API status code is 400
# Failed to fetch data for airport ID : 16869, API status code is 400
# Failed to fetch data for airport ID : 10408, API status code is 400
# For airport ID : 12264 API status code is 200
# For airport ID : 11618 API status code is 200
# For airport ID : 15304 API status code is 200
# For airport ID : 13577 API status code is 200
# For airport ID : 12954 API status code is 200
# Failed to fetch data for airport ID : 11624, API status code is 400
# Failed to fetch data for airport ID : 13541, API status code is 400
# Failed to fetch data for airport ID : 13422, API status code is 400
# For airport ID : 14057 API status code is 200
# For airport ID : 13232 API status code is 200
# For airport ID : 10800 API status code is 200
# Failed to fetch data for airport ID : 14689, API status code is 400
# Failed to fetch data for airport ID : 12391, API status code is 400
# Failed to fetch data for airport ID : 10868, API status code is 400
# Failed to fetch data for airport ID : 14711, API status code is 400
# For airport ID : 10257 API status code is 200
# Failed to fetch data for airport ID : 11067, API status code is 400
# Failed to fetch data for airport ID : 10562, API status code is 400
# Failed to fetch data for airport ID : 11695, API status code is 400
# For airport ID : 13796 API status code is 200
# Failed to fetch data for airport ID : 14109, API status code is 400
# Failed to fetch data for airport ID : 13970, API status code is 400
# For airport ID : 14193 API status code is 200
# Failed to fetch data for airport ID : 11076, API status code is 400
# Failed to fetch data for airport ID : 14092, API status code is 400
# Failed to fetch data for airport ID : 11122, API status code is 400
# Failed to fetch data for airport ID : 11288, API status code is 400
# Failed to fetch data for airport ID : 11308, API status code is 400
# Failed to fetch data for airport ID : 10754, API status code is 400
# Failed to fetch data for airport ID : 12884, API status code is 400
# For airport ID : 15376 API status code is 200
# Failed to fetch data for airport ID : 14588, API status code is 400
# For airport ID : 11884 API status code is 200
# Failed to fetch data for airport ID : 12915, API status code is 400
# For airport ID : 13851 API status code is 200
# For airport ID : 14843 API status code is 200
# Failed to fetch data for airport ID : 11603, API status code is 400
# Failed to fetch data for airport ID : 14457, API status code is 400
# Failed to fetch data for airport ID : 12206, API status code is 400
# Failed to fetch data for airport ID : 11252, API status code is 400
# Failed to fetch data for airport ID : 11905, API status code is 400
# For airport ID : 15412 API status code is 200
# Failed to fetch data for airport ID : 14120, API status code is 400
# Failed to fetch data for airport ID : 11980, API status code is 400
# Failed to fetch data for airport ID : 14025, API status code is 400
# Failed to fetch data for airport ID : 11150, API status code is 400
# Failed to fetch data for airport ID : 14709, API status code is 400
# Failed to fetch data for airport ID : 15897, API status code is 400
# For airport ID : 14107 API status code is 200
# Failed to fetch data for airport ID : 14006, API status code is 400
# For airport ID : 14747 API status code is 200
# Failed to fetch data for airport ID : 12902, API status code is 400
# Failed to fetch data for airport ID : 13061, API status code is 400
# Failed to fetch data for airport ID : 12016, API status code is 400
# Failed to fetch data for airport ID : 14794, API status code is 400
# Failed to fetch data for airport ID : 11921, API status code is 400
# Failed to fetch data for airport ID : 10731, API status code is 400
# Failed to fetch data for airport ID : 14828, API status code is 400
# For airport ID : 12889 API status code is 200
# Failed to fetch data for airport ID : 12441, API status code is 400
# Failed to fetch data for airport ID : 14802, API status code is 400
# Failed to fetch data for airport ID : 13230, API status code is 400
# Failed to fetch data for airport ID : 10631, API status code is 400
# For airport ID : 14492 API status code is 200
# Failed to fetch data for airport ID : 10141, API status code is 400
# For airport ID : 13204 API status code is 200
# For airport ID : 12992 API status code is 200
# Failed to fetch data for airport ID : 13184, API status code is 400
# Failed to fetch data for airport ID : 10643, API status code is 400
# Failed to fetch data for airport ID : 10333, API status code is 400
# Failed to fetch data for airport ID : 12255, API status code is 400
# Failed to fetch data for airport ID : 14487, API status code is 400
# Failed to fetch data for airport ID : 12129, API status code is 400
# Failed to fetch data for airport ID : 10551, API status code is 400
# For airport ID : 13871 API status code is 200
# Failed to fetch data for airport ID : 14256, API status code is 400
# For airport ID : 11066 API status code is 200
# Failed to fetch data for airport ID : 13377, API status code is 400
# For airport ID : 13487 API status code is 200
# Failed to fetch data for airport ID : 10627, API status code is 400
# Failed to fetch data for airport ID : 12335, API status code is 400
# Failed to fetch data for airport ID : 14633, API status code is 400
# Failed to fetch data for airport ID : 11274, API status code is 400
# Failed to fetch data for airport ID : 14543, API status code is 400
# For airport ID : 10299 API status code is 200
# Failed to fetch data for airport ID : 10158, API status code is 400
# Failed to fetch data for airport ID : 12951, API status code is 400
# Failed to fetch data for airport ID : 14004, API status code is 400
# Failed to fetch data for airport ID : 12544, API status code is 400
# Failed to fetch data for airport ID : 10739, API status code is 400
# Failed to fetch data for airport ID : 10165, API status code is 400
# Failed to fetch data for airport ID : 13964, API status code is 400
# Failed to fetch data for airport ID : 14314, API status code is 400
# Failed to fetch data for airport ID : 10990, API status code is 400
# Failed to fetch data for airport ID : 14812, API status code is 400
# For airport ID : 12339 API status code is 200
# Failed to fetch data for airport ID : 10561, API status code is 400
# Failed to fetch data for airport ID : 10146, API status code is 400
# For airport ID : 12451 API status code is 200
# Failed to fetch data for airport ID : 15991, API status code is 400
# For airport ID : 11423 API status code is 200
# Failed to fetch data for airport ID : 15401, API status code is 400
# Failed to fetch data for airport ID : 11587, API status code is 400
# Failed to fetch data for airport ID : 14520, API status code is 400
# For airport ID : 11042 API status code is 200
# Failed to fetch data for airport ID : 10185, API status code is 400
# For airport ID : 11278 API status code is 200
# Failed to fetch data for airport ID : 14534, API status code is 400
# For airport ID : 14100 API status code is 200
# For airport ID : 14321 API status code is 200
# Failed to fetch data for airport ID : 11111, API status code is 400
# Failed to fetch data for airport ID : 15024, API status code is 400
# Failed to fetch data for airport ID : 12917, API status code is 400
# Failed to fetch data for airport ID : 12124, API status code is 400
# Failed to fetch data for airport ID : 12523, API status code is 400
# For airport ID : 10821 API status code is 200
# For airport ID : 10721 API status code is 200
# Failed to fetch data for airport ID : 11630, API status code is 400
# Failed to fetch data for airport ID : 10170, API status code is 400
# Failed to fetch data for airport ID : 12448, API status code is 400
# For airport ID : 12953 API status code is 200
# Failed to fetch data for airport ID : 10918, API status code is 400
# Failed to fetch data for airport ID : 15356, API status code is 400
# Failed to fetch data for airport ID : 13344, API status code is 400
# Failed to fetch data for airport ID : 10676, API status code is 400
# Failed to fetch data for airport ID : 10926, API status code is 400
# For airport ID : 14307 API status code is 200
# For airport ID : 14635 API status code is 200
# Failed to fetch data for airport ID : 12156, API status code is 400
# Failed to fetch data for airport ID : 12244, API status code is 400
# Failed to fetch data for airport ID : 10666, API status code is 400
# Failed to fetch data for airport ID : 11612, API status code is 400
# Failed to fetch data for airport ID : 13476, API status code is 400
# Failed to fetch data for airport ID : 13029, API status code is 400
# For airport ID : 11267 API status code is 200
# Failed to fetch data for airport ID : 15411, API status code is 400
# Failed to fetch data for airport ID : 14986, API status code is 400
# Failed to fetch data for airport ID : 11471, API status code is 400
# For airport ID : 12758 API status code is 200
# For airport ID : 14576 API status code is 200
# Failed to fetch data for airport ID : 10155, API status code is 400
# Failed to fetch data for airport ID : 13486, API status code is 400
# Failed to fetch data for airport ID : 14716, API status code is 400
# Failed to fetch data for airport ID : 13296, API status code is 400
# Failed to fetch data for airport ID : 11283, API status code is 400
# Failed to fetch data for airport ID : 10732, API status code is 400
# For airport ID : 12266 API status code is 200
# For airport ID : 12892 API status code is 200
# Failed to fetch data for airport ID : 11003, API status code is 400
# Failed to fetch data for airport ID : 12094, API status code is 400
# For airport ID : 14685 API status code is 200
# Failed to fetch data for airport ID : 13158, API status code is 400
# Failed to fetch data for airport ID : 13121, API status code is 400
# For airport ID : 11540 API status code is 200
# Failed to fetch data for airport ID : 14877, API status code is 400
# Failed to fetch data for airport ID : 12217, API status code is 400
# For airport ID : 11697 API status code is 200
# Failed to fetch data for airport ID : 10372, API status code is 400
# Failed to fetch data for airport ID : 13264, API status code is 400
# Failed to fetch data for airport ID : 10469, API status code is 400
# Failed to fetch data for airport ID : 11336, API status code is 400
# For airport ID : 14683 API status code is 200
# Failed to fetch data for airport ID : 14112, API status code is 400
# Failed to fetch data for airport ID : 13502, API status code is 400
# For airport ID : 14524 API status code is 200
# Failed to fetch data for airport ID : 15027, API status code is 400
# Failed to fetch data for airport ID : 11973, API status code is 400
# For airport ID : 12173 API status code is 200
# Failed to fetch data for airport ID : 10361, API status code is 400
# Failed to fetch data for airport ID : 13388, API status code is 400
# For airport ID : 13891 API status code is 200
# Failed to fetch data for airport ID : 10577, API status code is 400
# For airport ID : 11433 API status code is 200
# Failed to fetch data for airport ID : 13290, API status code is 400
# For airport ID : 11298 API status code is 200
# For airport ID : 14771 API status code is 200
# Failed to fetch data for airport ID : 11577, API status code is 400
# Failed to fetch data for airport ID : 11140, API status code is 400
# For airport ID : 11057 API status code is 200
# Failed to fetch data for airport ID : 15048, API status code is 400
# Failed to fetch data for airport ID : 14960, API status code is 400
# Failed to fetch data for airport ID : 15295, API status code is 400
# Failed to fetch data for airport ID : 11865, API status code is 400
# For airport ID : 14893 API status code is 200
# Failed to fetch data for airport ID : 11049, API status code is 400
# For airport ID : 13495 API status code is 200
# Failed to fetch data for airport ID : 11953, API status code is 400
# Failed to fetch data for airport ID : 12223, API status code is 400
# Failed to fetch data for airport ID : 14254, API status code is 400
# Failed to fetch data for airport ID : 11823, API status code is 400
# Failed to fetch data for airport ID : 15380, API status code is 400
# Failed to fetch data for airport ID : 11447, API status code is 400
# Failed to fetch data for airport ID : 12003, API status code is 400
# Failed to fetch data for airport ID : 14489, API status code is 400
# For airport ID : 14908 API status code is 200
# For airport ID : 11986 API status code is 200
# Failed to fetch data for airport ID : 14082, API status code is 400
# For airport ID : 12191 API status code is 200
# Failed to fetch data for airport ID : 14113, API status code is 400
# Failed to fetch data for airport ID : 12891, API status code is 400
# Failed to fetch data for airport ID : 15249, API status code is 400
# Failed to fetch data for airport ID : 12819, API status code is 400
# For airport ID : 14570 API status code is 200
# Failed to fetch data for airport ID : 12323, API status code is 400
# For airport ID : 14679 API status code is 200
# Failed to fetch data for airport ID : 12343, API status code is 400
# Failed to fetch data for airport ID : 13076, API status code is 400
# Failed to fetch data for airport ID : 11503, API status code is 400
# Failed to fetch data for airport ID : 11617, API status code is 400
# Failed to fetch data for airport ID : 10728, API status code is 400
# Failed to fetch data for airport ID : 10785, API status code is 400
# For airport ID : 14869 API status code is 200
# For airport ID : 14027 API status code is 200
# Failed to fetch data for airport ID : 14674, API status code is 400
# Failed to fetch data for airport ID : 12197, API status code is 400
# Failed to fetch data for airport ID : 14696, API status code is 400
# For airport ID : 13485 API status code is 200
# Failed to fetch data for airport ID : 10781, API status code is 400
# Failed to fetch data for airport ID : 10849, API status code is 400
# Failed to fetch data for airport ID : 14955, API status code is 400
# Failed to fetch data for airport ID : 13433, API status code is 400
# Failed to fetch data for airport ID : 15074, API status code is 400
# Failed to fetch data for airport ID : 13127, API status code is 400
# Failed to fetch data for airport ID : 11013, API status code is 400
# For airport ID : 14122 API status code is 200
# Failed to fetch data for airport ID : 10154, API status code is 400
# Failed to fetch data for airport ID : 10980, API status code is 400
# Failed to fetch data for airport ID : 14098, API status code is 400
# For airport ID : 12982 API status code is 200
# Failed to fetch data for airport ID : 14512, API status code is 400
# Failed to fetch data for airport ID : 12278, API status code is 400
# For airport ID : 15919 API status code is 200
# For airport ID : 12478 API status code is 200
# For airport ID : 13830 API status code is 200
# Failed to fetch data for airport ID : 13933, API status code is 400
# For airport ID : 13930 API status code is 200
# Failed to fetch data for airport ID : 11997, API status code is 400
# Failed to fetch data for airport ID : 11027, API status code is 400
# Failed to fetch data for airport ID : 15582, API status code is 400
# Failed to fetch data for airport ID : 11721, API status code is 400
# Failed to fetch data for airport ID : 12896, API status code is 400
# Failed to fetch data for airport ID : 10279, API status code is 400
# Failed to fetch data for airport ID : 11778, API status code is 400
# Failed to fetch data for airport ID : 12888, API status code is 400
# For airport ID : 14262 API status code is 200
# Failed to fetch data for airport ID : 11415, API status code is 400
# Failed to fetch data for airport ID : 10685, API status code is 400
# Failed to fetch data for airport ID : 14842, API status code is 400
# For airport ID : 14761 API status code is 200
# For airport ID : 11193 API status code is 200
# Failed to fetch data for airport ID : 12265, API status code is 400
# Failed to fetch data for airport ID : 14288, API status code is 400
# For airport ID : 10713 API status code is 200
# Failed to fetch data for airport ID : 12397, API status code is 400
# Failed to fetch data for airport ID : 15624, API status code is 400
# For airport ID : 10994 API status code is 200
# Failed to fetch data for airport ID : 10409, API status code is 400
# Failed to fetch data for airport ID : 12519, API status code is 400
# Failed to fetch data for airport ID : 10136, API status code is 400
# Failed to fetch data for airport ID : 15607, API status code is 400
# Failed to fetch data for airport ID : 14237, API status code is 400
# Failed to fetch data for airport ID : 10779, API status code is 400
# Failed to fetch data for airport ID : 11898, API status code is 400
# Failed to fetch data for airport ID : 11413, API status code is 400
# Failed to fetch data for airport ID : 13983, API status code is 400
# Failed to fetch data for airport ID : 10558, API status code is 400
# Failed to fetch data for airport ID : 10620, API status code is 400
# Failed to fetch data for airport ID : 14222, API status code is 400
# For airport ID : 13198 API status code is 200
# For airport ID : 10423 API status code is 200
# Failed to fetch data for airport ID : 11097, API status code is 400
# Failed to fetch data for airport ID : 15454, API status code is 400
# For airport ID : 15370 API status code is 200
# Failed to fetch data for airport ID : 12899, API status code is 400
# Failed to fetch data for airport ID : 10135, API status code is 400
# Failed to fetch data for airport ID : 12177, API status code is 400
# For airport ID : 13303 API status code is 200
# Failed to fetch data for airport ID : 13795, API status code is 400
# For airport ID : 10693 API status code is 200
# Failed to fetch data for airport ID : 12945, API status code is 400
# Failed to fetch data for airport ID : 12511, API status code is 400
# --------------------------------------------------------------------------
# Total processing time: 2 minutes and 21 seconds
# --------------------------------------------------------------------------

# %%
len(all_API_airports_in_list)
# Out:
# 97

# %%
all_API_airports_in_list[0]
# Out:
# {'ORIGIN_AIRPORT_ID': 11638,
#  'DISPLAY_AIRPORT_NAME': 'Fresno Air Terminal',
#  'ORIGIN_CITY_NAME': 'Fresno, CA',
#  'NAME': 'FRESNO YOSEMITE INTERNATIONAL, CA US'}

# %% [markdown]
# Zapisuje dane do ramki `airport_df`: najpierw do listy ramek danych używając metody Pandas `from_records`, następnie za pomocą funkcji `concat` łączę dane do jednej ramki danych.

# %%
df_temp_list = []

for i in range(0, len(all_API_airports_in_list)):
    df_temp = pd.DataFrame.from_records(all_API_airports_in_list[i], index=[0])
    df_temp_list.append(df_temp)

airport_df = pd.concat(df_temp_list, ignore_index=True)

# %%
airport_df.shape
# Out:
# (97, 4)

# %%
airport_df.tail()
# Out:
#                 DISPLAY_AIRPORT_NAME  \
# 92         Kansas City International
# 93  Austin - Bergstrom International
# 94               Tulsa International
# 95               Miami International
# 96        Myrtle Beach International
#
#                                               NAME  ORIGIN_AIRPORT_ID  \
# 92        KANSAS CITY INTERNATIONAL AIRPORT, MO US              13198
# 93   AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US              10423
# 94  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US              15370
# 95              MIAMI INTERNATIONAL AIRPORT, FL US              13303
# 96                       NORTH MYRTLE BEACH, SC US              10693
#
#     ORIGIN_CITY_NAME
# 92   Kansas City, MO
# 93        Austin, TX
# 94         Tulsa, OK
# 95         Miami, FL
# 96  Myrtle Beach, SC

# %%
airport_df.describe()
# Out:
#        ORIGIN_AIRPORT_ID
# count          97.000000
# mean        12975.000000
# std          1584.854679
# min         10140.000000
# 25%         11433.000000
# 50%         13204.000000
# 75%         14321.000000
# max         15919.000000

# %%
airport_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DISPLAY_AIRPORT_NAME  97 non-null     object
#  1   NAME                  97 non-null     object
#  2   ORIGIN_AIRPORT_ID     97 non-null     int64
#  3   ORIGIN_CITY_NAME      97 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.2+ KB

# %% [markdown]
#  ## Sprawdzenie
# Kod poniżej sprawdza, czy ta część została poprawnie wykonana

# %%
airport_df_expected_shape = (97, 4)
assert airport_df_expected_shape == airport_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Zapisuję ramkę `airport_df` do pliku `airport_list.csv` w katalogu `data\raw`

# %%
airport_df.to_csv(r"..\data\raw\airport_list.csv")

# %% [markdown]
#  # Pobieranie `Weather`
#
#  - Data początkowa danych to `2019-01-01`, zaś data końcowa to `2020-03-31`, czyli 15 miesięcy,

# %% [markdown]
#  Do endpoint'u `weather` potrzebuję poszczególnych miesięcy. Tworzę listę miesięcy, korzystając z modułu `datetime`, formatowania daty `strftime`, inkrementacji z pomocą klasy `relativedelta`.

# %%
year_month_list = []
start_date = datetime.date(2019, 1, 1)
end_date = datetime.date(2020, 4, 1) # tutaj moze byc 03.2020 i wtedy w pętli while i <= end_date:
i = start_date
while i < end_date:
    year_month_list.append(i.strftime("%Y-%m"))
    i = i + relativedelta(months =+ 1)
print(year_month_list)
# Out:
# ['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03']

# %% [markdown]
#  Pobieram dane z endpoint'u `weather` do listy.

# %%
all_API_airport_weather_in_list = []
total_processing_time = 0

for year_month in year_month_list:
    start_time = time.time()
    response = requests.get(f'https://api-datalab.coderslab.com/api/v2/airportWeather?date={year_month}', headers=headers)
    try:
        if response.status_code == 200:
            data = response.json()
            all_API_airport_weather_in_list.append(data)
            print(f"For year_month : {year_month} API status code is {response.status_code}")
        else:
            print(f"Failed to fetch data for year_month : {year_month}, API status code is {response.status_code}")
    except Exception as e:
        print(f"An error occurred while processing year_month : {year_month}. Error message: {str(e)}")
        continue
    
    end_time = time.time()
    processing_time = end_time - start_time
    total_processing_time += processing_time

    time.sleep(1)

total_minutes = int(total_processing_time // 60)
total_seconds = int(total_processing_time % 60)

print("--------------------------------------------------------------------------")
print(f"Total processing time: {total_minutes} minutes and {total_seconds} seconds")
print("--------------------------------------------------------------------------")
# Out:
# For year_month : 2019-01 API status code is 200
# For year_month : 2019-02 API status code is 200
# For year_month : 2019-03 API status code is 200
# For year_month : 2019-04 API status code is 200
# For year_month : 2019-05 API status code is 200
# For year_month : 2019-06 API status code is 200
# For year_month : 2019-07 API status code is 200
# For year_month : 2019-08 API status code is 200
# For year_month : 2019-09 API status code is 200
# For year_month : 2019-10 API status code is 200
# For year_month : 2019-11 API status code is 200
# For year_month : 2019-12 API status code is 200
# For year_month : 2020-01 API status code is 200
# For year_month : 2020-02 API status code is 200
# For year_month : 2020-03 API status code is 200
# --------------------------------------------------------------------------
# Total processing time: 0 minutes and 16 seconds
# --------------------------------------------------------------------------

# %%
len(all_API_airport_weather_in_list)
# Out:
# 15

# %%
len(all_API_airport_weather_in_list[0])
# Out:
# 3286

# %%
all_API_airport_weather_in_list[0][0] # lista zawiera listy ze słownikami, ponieważ 1 miesiąc z endpointu zwraca dane dla każdego dnia, dlatego trzeba wejść głębiej w strukturę danych.
# Out:
# {'WT18': None,
#  'STATION': 'USW00013874',
#  'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#  'DATE': '2019-01-01',
#  'AWND': 4.7,
#  'PRCP': 0.14,
#  'SNOW': 0,
#  'SNWD': 0,
#  'TAVG': 64,
#  'TMAX': 66,
#  'TMIN': 57,
#  'WDF2': 310,
#  'WDF5': 310,
#  'WSF2': 15,
#  'WSF5': 19,
#  'WT01': 1}

# %% [markdown]
# Zapisuje dane do ramki `airport_weather_df`: najpierw do listy ramek danych używając metody Pandas `from_records`, następnie za pomocą funkcji `concat` łączę dane do jednej ramki danych.

# %%
df_temp_list = []

for i in range(0, len(all_API_airport_weather_in_list)):
    for j in range(0, len(all_API_airport_weather_in_list[i])):
        df_temp = pd.DataFrame.from_records(all_API_airport_weather_in_list[i][j], index=[0])
        df_temp_list.append(df_temp)

airport_weather_df = pd.concat(df_temp_list, ignore_index=True)

# %%
airport_weather_df.shape
# Out:
# (46226, 33)

# %%
airport_weather_df.tail()
# Out:
#         AWND        DATE                                    NAME  PRCP  SNOW  \
# 46221   3.58  2020-03-27  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  0.21   NaN
# 46222   6.93  2020-03-28  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  1.29   NaN
# 46223  16.55  2020-03-29  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  0.02   NaN
# 46224  13.42  2020-03-30  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  0.00   NaN
# 46225   3.80  2020-03-31  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  0.06   NaN
#
#        SNWD      STATION  TAVG  TMAX  TMIN  ...    PGTM  WT10  WESD  SN32  \
# 46221   NaN  USW00014762   NaN  59.0  49.0  ...   146.0   NaN   NaN   NaN
# 46222   NaN  USW00014762   NaN  77.0  51.0  ...  1535.0   NaN   NaN   NaN
# 46223   NaN  USW00014762   NaN  78.0  57.0  ...  1408.0   NaN   NaN   NaN
# 46224   NaN  USW00014762   NaN  57.0  42.0  ...   817.0   NaN   NaN   NaN
# 46225   NaN  USW00014762   NaN  47.0  39.0  ...   110.0   NaN   NaN   NaN
#
#        SX32 PSUN  TSUN  TOBS  WT07  WT11
# 46221   NaN  NaN   NaN   NaN   NaN   NaN
# 46222   NaN  NaN   NaN   NaN   NaN   NaN
# 46223   NaN  NaN   NaN   NaN   NaN   NaN
# 46224   NaN  NaN   NaN   NaN   NaN   NaN
# 46225   NaN  NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 33 columns]

# %%
airport_weather_df.describe()
# Out:
#                AWND          PRCP          SNOW          SNWD          TAVG  \
# count  45845.000000  46197.000000  32338.000000  31750.000000  34625.000000
# mean       8.041885      0.110614      0.055353      0.364189     57.708823
# std        3.751485      0.338897      0.462628      1.766932     18.773347
# min        0.000000      0.000000      0.000000      0.000000    -22.000000
# 25%        5.370000      0.000000      0.000000      0.000000     44.000000
# 50%        7.380000      0.000000      0.000000      0.000000     59.000000
# 75%       10.070000      0.040000      0.000000      0.000000     74.000000
# max       33.780000     11.630000     17.000000     25.000000    103.000000
#
#                TMAX          TMIN          WDF2          WDF5          WSF2  \
# count  46203.000000  46200.000000  45854.000000  45704.000000  45854.000000
# mean      67.765015     48.806580    200.300083    200.136662     18.693850
# std       19.753157     18.852169    101.702095    101.493734      6.490189
# min      -14.000000    -39.000000     10.000000      3.000000      1.100000
# 25%       53.000000     35.000000    120.000000    120.000000     14.100000
# 50%       70.000000     50.000000    200.000000    210.000000     17.000000
# 75%       84.000000     65.000000    290.000000    290.000000     21.900000
# max      120.000000     93.000000    360.000000    360.000000     62.000000
#
#        ...         PGTM  WT10  WESD        SN32        SX32        PSUN  \
# count  ...  4484.000000   5.0   7.0  453.000000  454.000000  430.000000
# mean   ...  1308.886262   1.0   0.0   64.600442   71.339207   35.074419
# std    ...   580.823669   0.0   0.0   11.916067   12.245805   35.946983
# min    ...     0.000000   1.0   0.0   44.000000   50.000000    0.000000
# 25%    ...  1047.000000   1.0   0.0   54.000000   60.000000    0.000000
# 50%    ...  1400.000000   1.0   0.0   62.000000   69.500000   21.500000
# 75%    ...  1637.250000   1.0   0.0   78.000000   84.000000   69.000000
# max    ...  2359.000000   1.0   0.0   83.000000   94.000000  100.000000
#
#              TSUN        TOBS  WT07  WT11
# count  429.000000  355.000000  28.0   1.0
# mean   261.335664   61.512676   1.0   1.0
# std    275.225989   13.300811   0.0   NaN
# min      0.000000   30.000000   1.0   1.0
# 25%      1.000000   51.000000   1.0   1.0
# 50%    154.000000   65.000000   1.0   1.0
# 75%    508.000000   73.000000   1.0   1.0
# max    908.000000   79.000000   1.0   1.0
#
# [8 rows x 29 columns]

# %%
airport_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46226 entries, 0 to 46225
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AWND     45845 non-null  float64
#  1   DATE     46226 non-null  object
#  2   NAME     46226 non-null  object
#  3   PRCP     46197 non-null  float64
#  4   SNOW     32338 non-null  float64
#  5   SNWD     31750 non-null  float64
#  6   STATION  46226 non-null  object
#  7   TAVG     34625 non-null  float64
#  8   TMAX     46203 non-null  float64
#  9   TMIN     46200 non-null  float64
#  10  WDF2     45854 non-null  float64
#  11  WDF5     45704 non-null  float64
#  12  WSF2     45854 non-null  float64
#  13  WSF5     45704 non-null  float64
#  14  WT01     16798 non-null  float64
#  15  WT18     0 non-null      object
#  16  WT08     5589 non-null   float64
#  17  WT02     2268 non-null   float64
#  18  WT03     5085 non-null   float64
#  19  WT04     362 non-null    float64
#  20  WT09     316 non-null    float64
#  21  WT06     522 non-null    float64
#  22  WT05     146 non-null    float64
#  23  PGTM     4484 non-null   float64
#  24  WT10     5 non-null      float64
#  25  WESD     7 non-null      float64
#  26  SN32     453 non-null    float64
#  27  SX32     454 non-null    float64
#  28  PSUN     430 non-null    float64
#  29  TSUN     429 non-null    float64
#  30  TOBS     355 non-null    float64
#  31  WT07     28 non-null     float64
#  32  WT11     1 non-null      float64
# dtypes: float64(29), object(4)
# memory usage: 11.6+ MB

# %% [markdown]
#  ## Sprawdzenie
#  Kod poniżej sprawdza, czy ta część została poprawnie wykonana

# %%
airport_weather_df_expected_shape = (46226, 33)
assert airport_weather_df_expected_shape == airport_weather_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Zapisuję ramkę `airport_weather_df` do pliku `airport_weather.csv` w katalogu `data\raw`

# %%
airport_weather_df.to_csv(r"..\data\raw\airport_weather.csv")

# %% [markdown]
#  # Pobranie `Aircraft`

# %% [markdown]
#  Pobieram dane z endpoint'u `aircraft` do ramki danych za pomocą metody `from_records`.

# %%
start_time = time.time()

response = requests.get(f'https://api-datalab.coderslab.com/api/v2/aircraft', headers=headers)
data = response.json()
aircraft_df = pd.DataFrame.from_records(data)

end_time = time.time()
processing_time = end_time - start_time

total_minutes = int(processing_time // 60)
total_seconds = int(processing_time % 60)

print("--------------------------------------------------------------------------")
print(f"Total processing time: {total_minutes} minutes and {total_seconds} seconds")
print("--------------------------------------------------------------------------")
# Out:
# --------------------------------------------------------------------------
# Total processing time: 0 minutes and 1 seconds
# --------------------------------------------------------------------------

# %%
aircraft_df.shape
# Out:
# (7383, 3)

# %%
aircraft_df.tail()
# Out:
#       MANUFACTURE_YEAR TAIL_NUM  NUMBER_OF_SEATS
# 7378              2019   N14011            337.0
# 7379              2019   N16008            337.0
# 7380              2019   N16009            337.0
# 7381              2019   N2250U            276.0
# 7382              2019   N2749U            276.0

# %%
aircraft_df.describe()
# Out:
#        MANUFACTURE_YEAR  NUMBER_OF_SEATS
# count       7383.000000      7376.000000
# mean        2005.135717       118.390591
# std            9.617305        77.714492
# min         1944.000000         0.000000
# 25%         1999.000000        66.000000
# 50%         2005.000000       143.000000
# 75%         2014.000000       175.000000
# max         2019.000000       524.000000

# %%
aircraft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7383 entries, 0 to 7382
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MANUFACTURE_YEAR  7383 non-null   int64
#  1   TAIL_NUM          7383 non-null   object
#  2   NUMBER_OF_SEATS   7376 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 173.2+ KB

# %% [markdown]
#  ## Sprawdzenie
#  Kod poniżej sprawdza, czy ta część została poprawnie wykonana

# %%
aircraft_df_expected_shape = (7383, 3)
assert aircraft_df_expected_shape == aircraft_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Zapisuję ramkę `aircraft_df` do pliku `aircraft.csv` w katalogu `data\raw`

# %%
aircraft_df.to_csv(r"..\data\raw\aircraft.csv")

# %% [markdown]
#  # Pobranie `Flight`

# %% [markdown]
#  * Pobieram dane z endpoint'u `flight` do listy.
#
#  W trakcie pracy ze wskazanym API sprawdziłam, że jeśli dla danego lotniska występują dane, to są one dostępne dla każdego miesiąca z zakresu.
#
#  > Celem automatyzacji kodu przeprowadzam wstępną weryfikację dla wszystkich lotnisk i przykładowego miesiąca w pierwszej pętli.
#  > Jeśli odpowiedź z API to 200 wtedy uruchamia się pętla dla każdego miesiąca z osobna.
#
#  > Gdyby sytuacja była inna/niepewna, wtedy kod byłby zmodyfikowany do przejścia w zagnieżdżonej pętli przez każde lotniko i każdy miesiąc.

# %%
all_API_flights_in_list = []
total_processing_time = 0

for airportId in airports_list:
    start_time = time.time() 
    response_init = requests.get(f'https://api-datalab.coderslab.com/api/v2/flight?airportId={airportId}&date=2019-01', headers=headers)
    try:
        if response_init.status_code == 200:
          for year_month in year_month_list:
              response = requests.get(f'https://api-datalab.coderslab.com/api/v2/flight?airportId={airportId}&date={year_month}', headers=headers)
              data = response.json()
              all_API_flights_in_list.append(data)
              print(f"For airport ID {airportId} and year_month : {year_month} API status code is {response.status_code}")
              time.sleep(6)
        elif response_init.status_code == 204:
              print(f"No content for airport ID {airportId}, API status code is {response_init.status_code}")
        else:
              print(f"For airport ID {airportId}, API status code is {response_init.status_code}")
    except Exception as e:
        print(f"An error occurred while processing airport ID {airportId} and year_month : {year_month}. Error message: {str(e)}")
        continue

    end_time = time.time()
    processing_time = end_time - start_time
    total_processing_time += processing_time

    time.sleep(6)

total_minutes = int(total_processing_time // 60)
total_seconds = int(total_processing_time % 60)

print("--------------------------------------------------------------------------")
print(f"Total processing time: {total_minutes} minutes and {total_seconds} seconds")
print("--------------------------------------------------------------------------") # cały kod 126m 11s
# Out:
# No content for airport ID 10874, API status code is 204
# No content for airport ID 11233, API status code is 204
# No content for airport ID 13360, API status code is 204
# No content for airport ID 15008, API status code is 204
# No content for airport ID 11638, API status code is 204
# No content for airport ID 14150, API status code is 204
# No content for airport ID 15323, API status code is 204
# No content for airport ID 14814, API status code is 204
# No content for airport ID 12007, API status code is 204
# No content for airport ID 11337, API status code is 204
# No content for airport ID 13342, API status code is 204
# No content for airport ID 15070, API status code is 204
# No content for airport ID 13244, API status code is 204
# No content for airport ID 12280, API status code is 204
# No content for airport ID 15096, API status code is 204
# No content for airport ID 11641, API status code is 204
# No content for airport ID 13832, API status code is 204
# No content for airport ID 10268, API status code is 204
# For airport ID 10397 and year_month : 2019-01 API status code is 200
# For airport ID 10397 and year_month : 2019-02 API status code is 200
# For airport ID 10397 and year_month : 2019-03 API status code is 200
# For airport ID 10397 and year_month : 2019-04 API status code is 200
# For airport ID 10397 and year_month : 2019-05 API status code is 200
# For airport ID 10397 and year_month : 2019-06 API status code is 200
# For airport ID 10397 and year_month : 2019-07 API status code is 200
# For airport ID 10397 and year_month : 2019-08 API status code is 200
# For airport ID 10397 and year_month : 2019-09 API status code is 200
# For airport ID 10397 and year_month : 2019-10 API status code is 200
# For airport ID 10397 and year_month : 2019-11 API status code is 200
# For airport ID 10397 and year_month : 2019-12 API status code is 200
# For airport ID 10397 and year_month : 2020-01 API status code is 200
# For airport ID 10397 and year_month : 2020-02 API status code is 200
# For airport ID 10397 and year_month : 2020-03 API status code is 200
# No content for airport ID 15041, API status code is 204
# No content for airport ID 10529, API status code is 204
# No content for airport ID 12119, API status code is 204
# No content for airport ID 11537, API status code is 204
# No content for airport ID 11092, API status code is 204
# No content for airport ID 10581, API status code is 204
# No content for airport ID 13829, API status code is 204
# No content for airport ID 15389, API status code is 204
# No content for airport ID 10140, API status code is 204
# No content for airport ID 12389, API status code is 204
# No content for airport ID 11648, API status code is 204
# No content for airport ID 15023, API status code is 204
# No content for airport ID 11982, API status code is 204
# No content for airport ID 10967, API status code is 204
# No content for airport ID 11525, API status code is 204
# No content for airport ID 10792, API status code is 204
# No content for airport ID 14259, API status code is 204
# No content for airport ID 11637, API status code is 204
# No content for airport ID 10466, API status code is 204
# No content for airport ID 10599, API status code is 204
# No content for airport ID 10208, API status code is 204
# No content for airport ID 15841, API status code is 204
# For airport ID 14831 and year_month : 2019-01 API status code is 200
# For airport ID 14831 and year_month : 2019-02 API status code is 200
# For airport ID 14831 and year_month : 2019-03 API status code is 200
# For airport ID 14831 and year_month : 2019-04 API status code is 200
# For airport ID 14831 and year_month : 2019-05 API status code is 200
# For airport ID 14831 and year_month : 2019-06 API status code is 200
# For airport ID 14831 and year_month : 2019-07 API status code is 200
# For airport ID 14831 and year_month : 2019-08 API status code is 200
# For airport ID 14831 and year_month : 2019-09 API status code is 200
# For airport ID 14831 and year_month : 2019-10 API status code is 200
# For airport ID 14831 and year_month : 2019-11 API status code is 200
# For airport ID 14831 and year_month : 2019-12 API status code is 200
# For airport ID 14831 and year_month : 2020-01 API status code is 200
# For airport ID 14831 and year_month : 2020-02 API status code is 200
# For airport ID 14831 and year_month : 2020-03 API status code is 200
# No content for airport ID 12898, API status code is 204
# No content for airport ID 13241, API status code is 204
# No content for airport ID 13367, API status code is 204
# No content for airport ID 11481, API status code is 204
# No content for airport ID 14108, API status code is 204
# No content for airport ID 13931, API status code is 204
# No content for airport ID 13873, API status code is 204
# No content for airport ID 10157, API status code is 204
# No content for airport ID 10245, API status code is 204
# No content for airport ID 11146, API status code is 204
# No content for airport ID 13277, API status code is 204
# For airport ID 11292 and year_month : 2019-01 API status code is 200
# For airport ID 11292 and year_month : 2019-02 API status code is 200
# For airport ID 11292 and year_month : 2019-03 API status code is 200
# For airport ID 11292 and year_month : 2019-04 API status code is 200
# For airport ID 11292 and year_month : 2019-05 API status code is 200
# For airport ID 11292 and year_month : 2019-06 API status code is 200
# For airport ID 11292 and year_month : 2019-07 API status code is 200
# For airport ID 11292 and year_month : 2019-08 API status code is 200
# For airport ID 11292 and year_month : 2019-09 API status code is 200
# For airport ID 11292 and year_month : 2019-10 API status code is 200
# For airport ID 11292 and year_month : 2019-11 API status code is 200
# For airport ID 11292 and year_month : 2019-12 API status code is 200
# For airport ID 11292 and year_month : 2020-01 API status code is 200
# For airport ID 11292 and year_month : 2020-02 API status code is 200
# For airport ID 11292 and year_month : 2020-03 API status code is 200
# No content for airport ID 11109, API status code is 204
# No content for airport ID 13459, API status code is 204
# No content for airport ID 11775, API status code is 204
# No content for airport ID 16218, API status code is 204
# No content for airport ID 14698, API status code is 204
# No content for airport ID 14252, API status code is 204
# No content for airport ID 13256, API status code is 204
# No content for airport ID 13139, API status code is 204
# No content for airport ID 12250, API status code is 204
# For airport ID 11259 and year_month : 2019-01 API status code is 200
# For airport ID 11259 and year_month : 2019-02 API status code is 200
# For airport ID 11259 and year_month : 2019-03 API status code is 200
# For airport ID 11259 and year_month : 2019-04 API status code is 200
# For airport ID 11259 and year_month : 2019-05 API status code is 200
# For airport ID 11259 and year_month : 2019-06 API status code is 200
# For airport ID 11259 and year_month : 2019-07 API status code is 200
# For airport ID 11259 and year_month : 2019-08 API status code is 200
# For airport ID 11259 and year_month : 2019-09 API status code is 200
# For airport ID 11259 and year_month : 2019-10 API status code is 200
# For airport ID 11259 and year_month : 2019-11 API status code is 200
# For airport ID 11259 and year_month : 2019-12 API status code is 200
# For airport ID 11259 and year_month : 2020-01 API status code is 200
# For airport ID 11259 and year_month : 2020-02 API status code is 200
# For airport ID 11259 and year_month : 2020-03 API status code is 200
# No content for airport ID 11468, API status code is 204
# No content for airport ID 14952, API status code is 204
# For airport ID 12402 and year_month : 2019-01 API status code is 200
# For airport ID 12402 and year_month : 2019-02 API status code is 200
# For airport ID 12402 and year_month : 2019-03 API status code is 200
# For airport ID 12402 and year_month : 2019-04 API status code is 200
# For airport ID 12402 and year_month : 2019-05 API status code is 200
# For airport ID 12402 and year_month : 2019-06 API status code is 200
# For airport ID 12402 and year_month : 2019-07 API status code is 200
# For airport ID 12402 and year_month : 2019-08 API status code is 200
# For airport ID 12402 and year_month : 2019-09 API status code is 200
# For airport ID 12402 and year_month : 2019-10 API status code is 200
# For airport ID 12402 and year_month : 2019-11 API status code is 200
# For airport ID 12402 and year_month : 2019-12 API status code is 200
# For airport ID 12402 and year_month : 2020-01 API status code is 200
# For airport ID 12402 and year_month : 2020-02 API status code is 200
# For airport ID 12402 and year_month : 2020-03 API status code is 200
# No content for airport ID 14574, API status code is 204
# No content for airport ID 11996, API status code is 204
# No content for airport ID 11977, API status code is 204
# No content for airport ID 11867, API status code is 204
# No content for airport ID 11203, API status code is 204
# No content for airport ID 11995, API status code is 204
# No content for airport ID 15016, API status code is 204
# No content for airport ID 10747, API status code is 204
# No content for airport ID 14905, API status code is 204
# No content for airport ID 12012, API status code is 204
# No content for airport ID 14783, API status code is 204
# No content for airport ID 14730, API status code is 204
# No content for airport ID 10431, API status code is 204
# No content for airport ID 10434, API status code is 204
# No content for airport ID 16869, API status code is 204
# No content for airport ID 10408, API status code is 204
# No content for airport ID 12264, API status code is 204
# For airport ID 11618 and year_month : 2019-01 API status code is 200
# For airport ID 11618 and year_month : 2019-02 API status code is 200
# For airport ID 11618 and year_month : 2019-03 API status code is 200
# For airport ID 11618 and year_month : 2019-04 API status code is 200
# For airport ID 11618 and year_month : 2019-05 API status code is 200
# For airport ID 11618 and year_month : 2019-06 API status code is 200
# For airport ID 11618 and year_month : 2019-07 API status code is 200
# For airport ID 11618 and year_month : 2019-08 API status code is 200
# For airport ID 11618 and year_month : 2019-09 API status code is 200
# For airport ID 11618 and year_month : 2019-10 API status code is 200
# For airport ID 11618 and year_month : 2019-11 API status code is 200
# For airport ID 11618 and year_month : 2019-12 API status code is 200
# For airport ID 11618 and year_month : 2020-01 API status code is 200
# For airport ID 11618 and year_month : 2020-02 API status code is 200
# For airport ID 11618 and year_month : 2020-03 API status code is 200
# For airport ID 15304 and year_month : 2019-01 API status code is 200
# For airport ID 15304 and year_month : 2019-02 API status code is 200
# For airport ID 15304 and year_month : 2019-03 API status code is 200
# For airport ID 15304 and year_month : 2019-04 API status code is 200
# For airport ID 15304 and year_month : 2019-05 API status code is 200
# For airport ID 15304 and year_month : 2019-06 API status code is 200
# For airport ID 15304 and year_month : 2019-07 API status code is 200
# For airport ID 15304 and year_month : 2019-08 API status code is 200
# For airport ID 15304 and year_month : 2019-09 API status code is 200
# For airport ID 15304 and year_month : 2019-10 API status code is 200
# For airport ID 15304 and year_month : 2019-11 API status code is 200
# For airport ID 15304 and year_month : 2019-12 API status code is 200
# For airport ID 15304 and year_month : 2020-01 API status code is 200
# For airport ID 15304 and year_month : 2020-02 API status code is 200
# For airport ID 15304 and year_month : 2020-03 API status code is 200
# No content for airport ID 13577, API status code is 204
# No content for airport ID 12954, API status code is 204
# No content for airport ID 11624, API status code is 204
# No content for airport ID 13541, API status code is 204
# No content for airport ID 13422, API status code is 204
# No content for airport ID 14057, API status code is 204
# No content for airport ID 13232, API status code is 204
# No content for airport ID 10800, API status code is 204
# No content for airport ID 14689, API status code is 204
# No content for airport ID 12391, API status code is 204
# No content for airport ID 10868, API status code is 204
# No content for airport ID 14711, API status code is 204
# No content for airport ID 10257, API status code is 204
# No content for airport ID 11067, API status code is 204
# No content for airport ID 10562, API status code is 204
# No content for airport ID 11695, API status code is 204
# No content for airport ID 13796, API status code is 204
# No content for airport ID 14109, API status code is 204
# No content for airport ID 13970, API status code is 204
# No content for airport ID 14193, API status code is 204
# No content for airport ID 11076, API status code is 204
# No content for airport ID 14092, API status code is 204
# No content for airport ID 11122, API status code is 204
# No content for airport ID 11288, API status code is 204
# No content for airport ID 11308, API status code is 204
# No content for airport ID 10754, API status code is 204
# No content for airport ID 12884, API status code is 204
# No content for airport ID 15376, API status code is 204
# No content for airport ID 14588, API status code is 204
# No content for airport ID 11884, API status code is 204
# No content for airport ID 12915, API status code is 204
# No content for airport ID 13851, API status code is 204
# No content for airport ID 14843, API status code is 204
# No content for airport ID 11603, API status code is 204
# No content for airport ID 14457, API status code is 204
# No content for airport ID 12206, API status code is 204
# No content for airport ID 11252, API status code is 204
# No content for airport ID 11905, API status code is 204
# No content for airport ID 15412, API status code is 204
# No content for airport ID 14120, API status code is 204
# No content for airport ID 11980, API status code is 204
# No content for airport ID 14025, API status code is 204
# No content for airport ID 11150, API status code is 204
# No content for airport ID 14709, API status code is 204
# No content for airport ID 15897, API status code is 204
# For airport ID 14107 and year_month : 2019-01 API status code is 200
# For airport ID 14107 and year_month : 2019-02 API status code is 200
# For airport ID 14107 and year_month : 2019-03 API status code is 200
# For airport ID 14107 and year_month : 2019-04 API status code is 200
# For airport ID 14107 and year_month : 2019-05 API status code is 200
# For airport ID 14107 and year_month : 2019-06 API status code is 200
# For airport ID 14107 and year_month : 2019-07 API status code is 200
# For airport ID 14107 and year_month : 2019-08 API status code is 200
# For airport ID 14107 and year_month : 2019-09 API status code is 200
# For airport ID 14107 and year_month : 2019-10 API status code is 200
# For airport ID 14107 and year_month : 2019-11 API status code is 200
# For airport ID 14107 and year_month : 2019-12 API status code is 200
# For airport ID 14107 and year_month : 2020-01 API status code is 200
# For airport ID 14107 and year_month : 2020-02 API status code is 200
# For airport ID 14107 and year_month : 2020-03 API status code is 200
# No content for airport ID 14006, API status code is 204
# For airport ID 14747 and year_month : 2019-01 API status code is 200
# For airport ID 14747 and year_month : 2019-02 API status code is 200
# For airport ID 14747 and year_month : 2019-03 API status code is 200
# For airport ID 14747 and year_month : 2019-04 API status code is 200
# For airport ID 14747 and year_month : 2019-05 API status code is 200
# For airport ID 14747 and year_month : 2019-06 API status code is 200
# For airport ID 14747 and year_month : 2019-07 API status code is 200
# For airport ID 14747 and year_month : 2019-08 API status code is 200
# For airport ID 14747 and year_month : 2019-09 API status code is 200
# For airport ID 14747 and year_month : 2019-10 API status code is 200
# For airport ID 14747 and year_month : 2019-11 API status code is 200
# For airport ID 14747 and year_month : 2019-12 API status code is 200
# For airport ID 14747 and year_month : 2020-01 API status code is 200
# For airport ID 14747 and year_month : 2020-02 API status code is 200
# For airport ID 14747 and year_month : 2020-03 API status code is 200
# No content for airport ID 12902, API status code is 204
# No content for airport ID 13061, API status code is 204
# No content for airport ID 12016, API status code is 204
# No content for airport ID 14794, API status code is 204
# No content for airport ID 11921, API status code is 204
# No content for airport ID 10731, API status code is 204
# No content for airport ID 14828, API status code is 204
# For airport ID 12889 and year_month : 2019-01 API status code is 200
# For airport ID 12889 and year_month : 2019-02 API status code is 200
# For airport ID 12889 and year_month : 2019-03 API status code is 200
# For airport ID 12889 and year_month : 2019-04 API status code is 200
# For airport ID 12889 and year_month : 2019-05 API status code is 200
# For airport ID 12889 and year_month : 2019-06 API status code is 200
# For airport ID 12889 and year_month : 2019-07 API status code is 200
# For airport ID 12889 and year_month : 2019-08 API status code is 200
# For airport ID 12889 and year_month : 2019-09 API status code is 200
# For airport ID 12889 and year_month : 2019-10 API status code is 200
# For airport ID 12889 and year_month : 2019-11 API status code is 200
# For airport ID 12889 and year_month : 2019-12 API status code is 200
# For airport ID 12889 and year_month : 2020-01 API status code is 200
# For airport ID 12889 and year_month : 2020-02 API status code is 200
# For airport ID 12889 and year_month : 2020-03 API status code is 200
# No content for airport ID 12441, API status code is 204
# No content for airport ID 14802, API status code is 204
# No content for airport ID 13230, API status code is 204
# No content for airport ID 10631, API status code is 204
# For airport ID 14492 and year_month : 2019-01 API status code is 200
# For airport ID 14492 and year_month : 2019-02 API status code is 200
# For airport ID 14492 and year_month : 2019-03 API status code is 200
# For airport ID 14492 and year_month : 2019-04 API status code is 200
# For airport ID 14492 and year_month : 2019-05 API status code is 200
# For airport ID 14492 and year_month : 2019-06 API status code is 200
# For airport ID 14492 and year_month : 2019-07 API status code is 200
# For airport ID 14492 and year_month : 2019-08 API status code is 200
# For airport ID 14492 and year_month : 2019-09 API status code is 200
# For airport ID 14492 and year_month : 2019-10 API status code is 200
# For airport ID 14492 and year_month : 2019-11 API status code is 200
# For airport ID 14492 and year_month : 2019-12 API status code is 200
# For airport ID 14492 and year_month : 2020-01 API status code is 200
# For airport ID 14492 and year_month : 2020-02 API status code is 200
# For airport ID 14492 and year_month : 2020-03 API status code is 200
# No content for airport ID 10141, API status code is 204
# For airport ID 13204 and year_month : 2019-01 API status code is 200
# For airport ID 13204 and year_month : 2019-02 API status code is 200
# For airport ID 13204 and year_month : 2019-03 API status code is 200
# For airport ID 13204 and year_month : 2019-04 API status code is 200
# For airport ID 13204 and year_month : 2019-05 API status code is 200
# For airport ID 13204 and year_month : 2019-06 API status code is 200
# For airport ID 13204 and year_month : 2019-07 API status code is 200
# For airport ID 13204 and year_month : 2019-08 API status code is 200
# For airport ID 13204 and year_month : 2019-09 API status code is 200
# For airport ID 13204 and year_month : 2019-10 API status code is 200
# For airport ID 13204 and year_month : 2019-11 API status code is 200
# For airport ID 13204 and year_month : 2019-12 API status code is 200
# For airport ID 13204 and year_month : 2020-01 API status code is 200
# For airport ID 13204 and year_month : 2020-02 API status code is 200
# For airport ID 13204 and year_month : 2020-03 API status code is 200
# No content for airport ID 12992, API status code is 204
# No content for airport ID 13184, API status code is 204
# No content for airport ID 10643, API status code is 204
# No content for airport ID 10333, API status code is 204
# No content for airport ID 12255, API status code is 204
# No content for airport ID 14487, API status code is 204
# No content for airport ID 12129, API status code is 204
# No content for airport ID 10551, API status code is 204
# No content for airport ID 13871, API status code is 204
# No content for airport ID 14256, API status code is 204
# No content for airport ID 11066, API status code is 204
# No content for airport ID 13377, API status code is 204
# For airport ID 13487 and year_month : 2019-01 API status code is 200
# For airport ID 13487 and year_month : 2019-02 API status code is 200
# For airport ID 13487 and year_month : 2019-03 API status code is 200
# For airport ID 13487 and year_month : 2019-04 API status code is 200
# For airport ID 13487 and year_month : 2019-05 API status code is 200
# For airport ID 13487 and year_month : 2019-06 API status code is 200
# For airport ID 13487 and year_month : 2019-07 API status code is 200
# For airport ID 13487 and year_month : 2019-08 API status code is 200
# For airport ID 13487 and year_month : 2019-09 API status code is 200
# For airport ID 13487 and year_month : 2019-10 API status code is 200
# For airport ID 13487 and year_month : 2019-11 API status code is 200
# For airport ID 13487 and year_month : 2019-12 API status code is 200
# For airport ID 13487 and year_month : 2020-01 API status code is 200
# For airport ID 13487 and year_month : 2020-02 API status code is 200
# For airport ID 13487 and year_month : 2020-03 API status code is 200
# No content for airport ID 10627, API status code is 204
# No content for airport ID 12335, API status code is 204
# No content for airport ID 14633, API status code is 204
# No content for airport ID 11274, API status code is 204
# No content for airport ID 14543, API status code is 204
# For airport ID 10299 and year_month : 2019-01 API status code is 200
# For airport ID 10299 and year_month : 2019-02 API status code is 200
# For airport ID 10299 and year_month : 2019-03 API status code is 200
# For airport ID 10299 and year_month : 2019-04 API status code is 200
# For airport ID 10299 and year_month : 2019-05 API status code is 200
# For airport ID 10299 and year_month : 2019-06 API status code is 200
# For airport ID 10299 and year_month : 2019-07 API status code is 200
# For airport ID 10299 and year_month : 2019-08 API status code is 200
# For airport ID 10299 and year_month : 2019-09 API status code is 200
# For airport ID 10299 and year_month : 2019-10 API status code is 200
# For airport ID 10299 and year_month : 2019-11 API status code is 200
# For airport ID 10299 and year_month : 2019-12 API status code is 200
# For airport ID 10299 and year_month : 2020-01 API status code is 200
# For airport ID 10299 and year_month : 2020-02 API status code is 200
# For airport ID 10299 and year_month : 2020-03 API status code is 200
# No content for airport ID 10158, API status code is 204
# No content for airport ID 12951, API status code is 204
# No content for airport ID 14004, API status code is 204
# No content for airport ID 12544, API status code is 204
# No content for airport ID 10739, API status code is 204
# No content for airport ID 10165, API status code is 204
# No content for airport ID 13964, API status code is 204
# No content for airport ID 14314, API status code is 204
# No content for airport ID 10990, API status code is 204
# No content for airport ID 14812, API status code is 204
# No content for airport ID 12339, API status code is 204
# No content for airport ID 10561, API status code is 204
# No content for airport ID 10146, API status code is 204
# No content for airport ID 12451, API status code is 204
# No content for airport ID 15991, API status code is 204
# No content for airport ID 11423, API status code is 204
# No content for airport ID 15401, API status code is 204
# No content for airport ID 11587, API status code is 204
# No content for airport ID 14520, API status code is 204
# No content for airport ID 11042, API status code is 204
# No content for airport ID 10185, API status code is 204
# For airport ID 11278 and year_month : 2019-01 API status code is 200
# For airport ID 11278 and year_month : 2019-02 API status code is 200
# For airport ID 11278 and year_month : 2019-03 API status code is 200
# For airport ID 11278 and year_month : 2019-04 API status code is 200
# For airport ID 11278 and year_month : 2019-05 API status code is 200
# For airport ID 11278 and year_month : 2019-06 API status code is 200
# For airport ID 11278 and year_month : 2019-07 API status code is 200
# For airport ID 11278 and year_month : 2019-08 API status code is 200
# For airport ID 11278 and year_month : 2019-09 API status code is 200
# For airport ID 11278 and year_month : 2019-10 API status code is 200
# For airport ID 11278 and year_month : 2019-11 API status code is 200
# For airport ID 11278 and year_month : 2019-12 API status code is 200
# For airport ID 11278 and year_month : 2020-01 API status code is 200
# For airport ID 11278 and year_month : 2020-02 API status code is 200
# For airport ID 11278 and year_month : 2020-03 API status code is 200
# No content for airport ID 14534, API status code is 204
# For airport ID 14100 and year_month : 2019-01 API status code is 200
# For airport ID 14100 and year_month : 2019-02 API status code is 200
# For airport ID 14100 and year_month : 2019-03 API status code is 200
# For airport ID 14100 and year_month : 2019-04 API status code is 200
# For airport ID 14100 and year_month : 2019-05 API status code is 200
# For airport ID 14100 and year_month : 2019-06 API status code is 200
# For airport ID 14100 and year_month : 2019-07 API status code is 200
# For airport ID 14100 and year_month : 2019-08 API status code is 200
# For airport ID 14100 and year_month : 2019-09 API status code is 200
# For airport ID 14100 and year_month : 2019-10 API status code is 200
# For airport ID 14100 and year_month : 2019-11 API status code is 200
# For airport ID 14100 and year_month : 2019-12 API status code is 200
# For airport ID 14100 and year_month : 2020-01 API status code is 200
# For airport ID 14100 and year_month : 2020-02 API status code is 200
# For airport ID 14100 and year_month : 2020-03 API status code is 200
# No content for airport ID 14321, API status code is 204
# No content for airport ID 11111, API status code is 204
# No content for airport ID 15024, API status code is 204
# No content for airport ID 12917, API status code is 204
# No content for airport ID 12124, API status code is 204
# No content for airport ID 12523, API status code is 204
# For airport ID 10821 and year_month : 2019-01 API status code is 200
# For airport ID 10821 and year_month : 2019-02 API status code is 200
# For airport ID 10821 and year_month : 2019-03 API status code is 200
# For airport ID 10821 and year_month : 2019-04 API status code is 200
# For airport ID 10821 and year_month : 2019-05 API status code is 200
# For airport ID 10821 and year_month : 2019-06 API status code is 200
# For airport ID 10821 and year_month : 2019-07 API status code is 200
# For airport ID 10821 and year_month : 2019-08 API status code is 200
# For airport ID 10821 and year_month : 2019-09 API status code is 200
# For airport ID 10821 and year_month : 2019-10 API status code is 200
# For airport ID 10821 and year_month : 2019-11 API status code is 200
# For airport ID 10821 and year_month : 2019-12 API status code is 200
# For airport ID 10821 and year_month : 2020-01 API status code is 200
# For airport ID 10821 and year_month : 2020-02 API status code is 200
# For airport ID 10821 and year_month : 2020-03 API status code is 200
# For airport ID 10721 and year_month : 2019-01 API status code is 200
# For airport ID 10721 and year_month : 2019-02 API status code is 200
# For airport ID 10721 and year_month : 2019-03 API status code is 200
# For airport ID 10721 and year_month : 2019-04 API status code is 200
# For airport ID 10721 and year_month : 2019-05 API status code is 200
# For airport ID 10721 and year_month : 2019-06 API status code is 200
# For airport ID 10721 and year_month : 2019-07 API status code is 200
# For airport ID 10721 and year_month : 2019-08 API status code is 200
# For airport ID 10721 and year_month : 2019-09 API status code is 200
# For airport ID 10721 and year_month : 2019-10 API status code is 200
# For airport ID 10721 and year_month : 2019-11 API status code is 200
# For airport ID 10721 and year_month : 2019-12 API status code is 200
# For airport ID 10721 and year_month : 2020-01 API status code is 200
# For airport ID 10721 and year_month : 2020-02 API status code is 200
# For airport ID 10721 and year_month : 2020-03 API status code is 200
# No content for airport ID 11630, API status code is 204
# No content for airport ID 10170, API status code is 204
# No content for airport ID 12448, API status code is 204
# For airport ID 12953 and year_month : 2019-01 API status code is 200
# For airport ID 12953 and year_month : 2019-02 API status code is 200
# For airport ID 12953 and year_month : 2019-03 API status code is 200
# For airport ID 12953 and year_month : 2019-04 API status code is 200
# For airport ID 12953 and year_month : 2019-05 API status code is 200
# For airport ID 12953 and year_month : 2019-06 API status code is 200
# For airport ID 12953 and year_month : 2019-07 API status code is 200
# For airport ID 12953 and year_month : 2019-08 API status code is 200
# For airport ID 12953 and year_month : 2019-09 API status code is 200
# For airport ID 12953 and year_month : 2019-10 API status code is 200
# For airport ID 12953 and year_month : 2019-11 API status code is 200
# For airport ID 12953 and year_month : 2019-12 API status code is 200
# For airport ID 12953 and year_month : 2020-01 API status code is 200
# For airport ID 12953 and year_month : 2020-02 API status code is 200
# For airport ID 12953 and year_month : 2020-03 API status code is 200
# No content for airport ID 10918, API status code is 204
# No content for airport ID 15356, API status code is 204
# No content for airport ID 13344, API status code is 204
# No content for airport ID 10676, API status code is 204
# No content for airport ID 10926, API status code is 204
# No content for airport ID 14307, API status code is 204
# No content for airport ID 14635, API status code is 204
# No content for airport ID 12156, API status code is 204
# No content for airport ID 12244, API status code is 204
# No content for airport ID 10666, API status code is 204
# No content for airport ID 11612, API status code is 204
# No content for airport ID 13476, API status code is 204
# No content for airport ID 13029, API status code is 204
# No content for airport ID 11267, API status code is 204
# No content for airport ID 15411, API status code is 204
# No content for airport ID 14986, API status code is 204
# No content for airport ID 11471, API status code is 204
# For airport ID 12758 and year_month : 2019-01 API status code is 200
# For airport ID 12758 and year_month : 2019-02 API status code is 200
# For airport ID 12758 and year_month : 2019-03 API status code is 200
# For airport ID 12758 and year_month : 2019-04 API status code is 200
# For airport ID 12758 and year_month : 2019-05 API status code is 200
# For airport ID 12758 and year_month : 2019-06 API status code is 200
# For airport ID 12758 and year_month : 2019-07 API status code is 200
# For airport ID 12758 and year_month : 2019-08 API status code is 200
# For airport ID 12758 and year_month : 2019-09 API status code is 200
# For airport ID 12758 and year_month : 2019-10 API status code is 200
# For airport ID 12758 and year_month : 2019-11 API status code is 200
# For airport ID 12758 and year_month : 2019-12 API status code is 200
# For airport ID 12758 and year_month : 2020-01 API status code is 200
# For airport ID 12758 and year_month : 2020-02 API status code is 200
# For airport ID 12758 and year_month : 2020-03 API status code is 200
# No content for airport ID 14576, API status code is 204
# No content for airport ID 10155, API status code is 204
# No content for airport ID 13486, API status code is 204
# No content for airport ID 14716, API status code is 204
# No content for airport ID 13296, API status code is 204
# No content for airport ID 11283, API status code is 204
# No content for airport ID 10732, API status code is 204
# For airport ID 12266 and year_month : 2019-01 API status code is 200
# For airport ID 12266 and year_month : 2019-02 API status code is 200
# For airport ID 12266 and year_month : 2019-03 API status code is 200
# For airport ID 12266 and year_month : 2019-04 API status code is 200
# For airport ID 12266 and year_month : 2019-05 API status code is 200
# For airport ID 12266 and year_month : 2019-06 API status code is 200
# For airport ID 12266 and year_month : 2019-07 API status code is 200
# For airport ID 12266 and year_month : 2019-08 API status code is 200
# For airport ID 12266 and year_month : 2019-09 API status code is 200
# For airport ID 12266 and year_month : 2019-10 API status code is 200
# For airport ID 12266 and year_month : 2019-11 API status code is 200
# For airport ID 12266 and year_month : 2019-12 API status code is 200
# For airport ID 12266 and year_month : 2020-01 API status code is 200
# For airport ID 12266 and year_month : 2020-02 API status code is 200
# For airport ID 12266 and year_month : 2020-03 API status code is 200
# For airport ID 12892 and year_month : 2019-01 API status code is 200
# For airport ID 12892 and year_month : 2019-02 API status code is 200
# For airport ID 12892 and year_month : 2019-03 API status code is 200
# For airport ID 12892 and year_month : 2019-04 API status code is 200
# For airport ID 12892 and year_month : 2019-05 API status code is 200
# For airport ID 12892 and year_month : 2019-06 API status code is 200
# For airport ID 12892 and year_month : 2019-07 API status code is 200
# For airport ID 12892 and year_month : 2019-08 API status code is 200
# For airport ID 12892 and year_month : 2019-09 API status code is 200
# For airport ID 12892 and year_month : 2019-10 API status code is 200
# For airport ID 12892 and year_month : 2019-11 API status code is 200
# For airport ID 12892 and year_month : 2019-12 API status code is 200
# For airport ID 12892 and year_month : 2020-01 API status code is 200
# For airport ID 12892 and year_month : 2020-02 API status code is 200
# For airport ID 12892 and year_month : 2020-03 API status code is 200
# No content for airport ID 11003, API status code is 204
# No content for airport ID 12094, API status code is 204
# No content for airport ID 14685, API status code is 204
# No content for airport ID 13158, API status code is 204
# No content for airport ID 13121, API status code is 204
# No content for airport ID 11540, API status code is 204
# No content for airport ID 14877, API status code is 204
# No content for airport ID 12217, API status code is 204
# For airport ID 11697 and year_month : 2019-01 API status code is 200
# For airport ID 11697 and year_month : 2019-02 API status code is 200
# For airport ID 11697 and year_month : 2019-03 API status code is 200
# For airport ID 11697 and year_month : 2019-04 API status code is 200
# For airport ID 11697 and year_month : 2019-05 API status code is 200
# For airport ID 11697 and year_month : 2019-06 API status code is 200
# For airport ID 11697 and year_month : 2019-07 API status code is 200
# For airport ID 11697 and year_month : 2019-08 API status code is 200
# For airport ID 11697 and year_month : 2019-09 API status code is 200
# For airport ID 11697 and year_month : 2019-10 API status code is 200
# For airport ID 11697 and year_month : 2019-11 API status code is 200
# For airport ID 11697 and year_month : 2019-12 API status code is 200
# For airport ID 11697 and year_month : 2020-01 API status code is 200
# For airport ID 11697 and year_month : 2020-02 API status code is 200
# For airport ID 11697 and year_month : 2020-03 API status code is 200
# No content for airport ID 10372, API status code is 204
# No content for airport ID 13264, API status code is 204
# No content for airport ID 10469, API status code is 204
# No content for airport ID 11336, API status code is 204
# No content for airport ID 14683, API status code is 204
# No content for airport ID 14112, API status code is 204
# No content for airport ID 13502, API status code is 204
# No content for airport ID 14524, API status code is 204
# No content for airport ID 15027, API status code is 204
# No content for airport ID 11973, API status code is 204
# For airport ID 12173 and year_month : 2019-01 API status code is 200
# For airport ID 12173 and year_month : 2019-02 API status code is 200
# For airport ID 12173 and year_month : 2019-03 API status code is 200
# For airport ID 12173 and year_month : 2019-04 API status code is 200
# For airport ID 12173 and year_month : 2019-05 API status code is 200
# For airport ID 12173 and year_month : 2019-06 API status code is 200
# For airport ID 12173 and year_month : 2019-07 API status code is 200
# For airport ID 12173 and year_month : 2019-08 API status code is 200
# For airport ID 12173 and year_month : 2019-09 API status code is 200
# For airport ID 12173 and year_month : 2019-10 API status code is 200
# For airport ID 12173 and year_month : 2019-11 API status code is 200
# For airport ID 12173 and year_month : 2019-12 API status code is 200
# For airport ID 12173 and year_month : 2020-01 API status code is 200
# For airport ID 12173 and year_month : 2020-02 API status code is 200
# For airport ID 12173 and year_month : 2020-03 API status code is 200
# No content for airport ID 10361, API status code is 204
# No content for airport ID 13388, API status code is 204
# No content for airport ID 13891, API status code is 204
# No content for airport ID 10577, API status code is 204
# For airport ID 11433 and year_month : 2019-01 API status code is 200
# For airport ID 11433 and year_month : 2019-02 API status code is 200
# For airport ID 11433 and year_month : 2019-03 API status code is 200
# For airport ID 11433 and year_month : 2019-04 API status code is 200
# For airport ID 11433 and year_month : 2019-05 API status code is 200
# For airport ID 11433 and year_month : 2019-06 API status code is 200
# For airport ID 11433 and year_month : 2019-07 API status code is 200
# For airport ID 11433 and year_month : 2019-08 API status code is 200
# For airport ID 11433 and year_month : 2019-09 API status code is 200
# For airport ID 11433 and year_month : 2019-10 API status code is 200
# For airport ID 11433 and year_month : 2019-11 API status code is 200
# For airport ID 11433 and year_month : 2019-12 API status code is 200
# For airport ID 11433 and year_month : 2020-01 API status code is 200
# For airport ID 11433 and year_month : 2020-02 API status code is 200
# For airport ID 11433 and year_month : 2020-03 API status code is 200
# No content for airport ID 13290, API status code is 204
# For airport ID 11298 and year_month : 2019-01 API status code is 200
# For airport ID 11298 and year_month : 2019-02 API status code is 200
# For airport ID 11298 and year_month : 2019-03 API status code is 200
# For airport ID 11298 and year_month : 2019-04 API status code is 200
# For airport ID 11298 and year_month : 2019-05 API status code is 200
# For airport ID 11298 and year_month : 2019-06 API status code is 200
# For airport ID 11298 and year_month : 2019-07 API status code is 200
# For airport ID 11298 and year_month : 2019-08 API status code is 200
# For airport ID 11298 and year_month : 2019-09 API status code is 200
# For airport ID 11298 and year_month : 2019-10 API status code is 200
# For airport ID 11298 and year_month : 2019-11 API status code is 200
# For airport ID 11298 and year_month : 2019-12 API status code is 200
# For airport ID 11298 and year_month : 2020-01 API status code is 200
# For airport ID 11298 and year_month : 2020-02 API status code is 200
# For airport ID 11298 and year_month : 2020-03 API status code is 200
# For airport ID 14771 and year_month : 2019-01 API status code is 200
# For airport ID 14771 and year_month : 2019-02 API status code is 200
# For airport ID 14771 and year_month : 2019-03 API status code is 200
# For airport ID 14771 and year_month : 2019-04 API status code is 200
# For airport ID 14771 and year_month : 2019-05 API status code is 200
# For airport ID 14771 and year_month : 2019-06 API status code is 200
# For airport ID 14771 and year_month : 2019-07 API status code is 200
# For airport ID 14771 and year_month : 2019-08 API status code is 200
# For airport ID 14771 and year_month : 2019-09 API status code is 200
# For airport ID 14771 and year_month : 2019-10 API status code is 200
# For airport ID 14771 and year_month : 2019-11 API status code is 200
# For airport ID 14771 and year_month : 2019-12 API status code is 200
# For airport ID 14771 and year_month : 2020-01 API status code is 200
# For airport ID 14771 and year_month : 2020-02 API status code is 200
# For airport ID 14771 and year_month : 2020-03 API status code is 200
# No content for airport ID 11577, API status code is 204
# No content for airport ID 11140, API status code is 204
# For airport ID 11057 and year_month : 2019-01 API status code is 200
# For airport ID 11057 and year_month : 2019-02 API status code is 200
# For airport ID 11057 and year_month : 2019-03 API status code is 200
# For airport ID 11057 and year_month : 2019-04 API status code is 200
# For airport ID 11057 and year_month : 2019-05 API status code is 200
# For airport ID 11057 and year_month : 2019-06 API status code is 200
# For airport ID 11057 and year_month : 2019-07 API status code is 200
# For airport ID 11057 and year_month : 2019-08 API status code is 200
# For airport ID 11057 and year_month : 2019-09 API status code is 200
# For airport ID 11057 and year_month : 2019-10 API status code is 200
# For airport ID 11057 and year_month : 2019-11 API status code is 200
# For airport ID 11057 and year_month : 2019-12 API status code is 200
# For airport ID 11057 and year_month : 2020-01 API status code is 200
# For airport ID 11057 and year_month : 2020-02 API status code is 200
# For airport ID 11057 and year_month : 2020-03 API status code is 200
# No content for airport ID 15048, API status code is 204
# No content for airport ID 14960, API status code is 204
# No content for airport ID 15295, API status code is 204
# No content for airport ID 11865, API status code is 204
# For airport ID 14893 and year_month : 2019-01 API status code is 200
# For airport ID 14893 and year_month : 2019-02 API status code is 200
# For airport ID 14893 and year_month : 2019-03 API status code is 200
# For airport ID 14893 and year_month : 2019-04 API status code is 200
# For airport ID 14893 and year_month : 2019-05 API status code is 200
# For airport ID 14893 and year_month : 2019-06 API status code is 200
# For airport ID 14893 and year_month : 2019-07 API status code is 200
# For airport ID 14893 and year_month : 2019-08 API status code is 200
# For airport ID 14893 and year_month : 2019-09 API status code is 200
# For airport ID 14893 and year_month : 2019-10 API status code is 200
# For airport ID 14893 and year_month : 2019-11 API status code is 200
# For airport ID 14893 and year_month : 2019-12 API status code is 200
# For airport ID 14893 and year_month : 2020-01 API status code is 200
# For airport ID 14893 and year_month : 2020-02 API status code is 200
# For airport ID 14893 and year_month : 2020-03 API status code is 200
# No content for airport ID 11049, API status code is 204
# For airport ID 13495 and year_month : 2019-01 API status code is 200
# For airport ID 13495 and year_month : 2019-02 API status code is 200
# For airport ID 13495 and year_month : 2019-03 API status code is 200
# For airport ID 13495 and year_month : 2019-04 API status code is 200
# For airport ID 13495 and year_month : 2019-05 API status code is 200
# For airport ID 13495 and year_month : 2019-06 API status code is 200
# For airport ID 13495 and year_month : 2019-07 API status code is 200
# For airport ID 13495 and year_month : 2019-08 API status code is 200
# For airport ID 13495 and year_month : 2019-09 API status code is 200
# For airport ID 13495 and year_month : 2019-10 API status code is 200
# For airport ID 13495 and year_month : 2019-11 API status code is 200
# For airport ID 13495 and year_month : 2019-12 API status code is 200
# For airport ID 13495 and year_month : 2020-01 API status code is 200
# For airport ID 13495 and year_month : 2020-02 API status code is 200
# For airport ID 13495 and year_month : 2020-03 API status code is 200
# No content for airport ID 11953, API status code is 204
# No content for airport ID 12223, API status code is 204
# No content for airport ID 14254, API status code is 204
# No content for airport ID 11823, API status code is 204
# No content for airport ID 15380, API status code is 204
# No content for airport ID 11447, API status code is 204
# No content for airport ID 12003, API status code is 204
# No content for airport ID 14489, API status code is 204
# No content for airport ID 14908, API status code is 204
# No content for airport ID 11986, API status code is 204
# No content for airport ID 14082, API status code is 204
# For airport ID 12191 and year_month : 2019-01 API status code is 200
# For airport ID 12191 and year_month : 2019-02 API status code is 200
# For airport ID 12191 and year_month : 2019-03 API status code is 200
# For airport ID 12191 and year_month : 2019-04 API status code is 200
# For airport ID 12191 and year_month : 2019-05 API status code is 200
# For airport ID 12191 and year_month : 2019-06 API status code is 200
# For airport ID 12191 and year_month : 2019-07 API status code is 200
# For airport ID 12191 and year_month : 2019-08 API status code is 200
# For airport ID 12191 and year_month : 2019-09 API status code is 200
# For airport ID 12191 and year_month : 2019-10 API status code is 200
# For airport ID 12191 and year_month : 2019-11 API status code is 200
# For airport ID 12191 and year_month : 2019-12 API status code is 200
# For airport ID 12191 and year_month : 2020-01 API status code is 200
# For airport ID 12191 and year_month : 2020-02 API status code is 200
# For airport ID 12191 and year_month : 2020-03 API status code is 200
# No content for airport ID 14113, API status code is 204
# No content for airport ID 12891, API status code is 204
# No content for airport ID 15249, API status code is 204
# No content for airport ID 12819, API status code is 204
# No content for airport ID 14570, API status code is 204
# No content for airport ID 12323, API status code is 204
# For airport ID 14679 and year_month : 2019-01 API status code is 200
# For airport ID 14679 and year_month : 2019-02 API status code is 200
# For airport ID 14679 and year_month : 2019-03 API status code is 200
# For airport ID 14679 and year_month : 2019-04 API status code is 200
# For airport ID 14679 and year_month : 2019-05 API status code is 200
# For airport ID 14679 and year_month : 2019-06 API status code is 200
# For airport ID 14679 and year_month : 2019-07 API status code is 200
# For airport ID 14679 and year_month : 2019-08 API status code is 200
# For airport ID 14679 and year_month : 2019-09 API status code is 200
# For airport ID 14679 and year_month : 2019-10 API status code is 200
# For airport ID 14679 and year_month : 2019-11 API status code is 200
# For airport ID 14679 and year_month : 2019-12 API status code is 200
# For airport ID 14679 and year_month : 2020-01 API status code is 200
# For airport ID 14679 and year_month : 2020-02 API status code is 200
# For airport ID 14679 and year_month : 2020-03 API status code is 200
# No content for airport ID 12343, API status code is 204
# No content for airport ID 13076, API status code is 204
# No content for airport ID 11503, API status code is 204
# No content for airport ID 11617, API status code is 204
# No content for airport ID 10728, API status code is 204
# No content for airport ID 10785, API status code is 204
# For airport ID 14869 and year_month : 2019-01 API status code is 200
# For airport ID 14869 and year_month : 2019-02 API status code is 200
# For airport ID 14869 and year_month : 2019-03 API status code is 200
# For airport ID 14869 and year_month : 2019-04 API status code is 200
# For airport ID 14869 and year_month : 2019-05 API status code is 200
# For airport ID 14869 and year_month : 2019-06 API status code is 200
# For airport ID 14869 and year_month : 2019-07 API status code is 200
# For airport ID 14869 and year_month : 2019-08 API status code is 200
# For airport ID 14869 and year_month : 2019-09 API status code is 200
# For airport ID 14869 and year_month : 2019-10 API status code is 200
# For airport ID 14869 and year_month : 2019-11 API status code is 200
# For airport ID 14869 and year_month : 2019-12 API status code is 200
# For airport ID 14869 and year_month : 2020-01 API status code is 200
# For airport ID 14869 and year_month : 2020-02 API status code is 200
# For airport ID 14869 and year_month : 2020-03 API status code is 200
# No content for airport ID 14027, API status code is 204
# No content for airport ID 14674, API status code is 204
# No content for airport ID 12197, API status code is 204
# No content for airport ID 14696, API status code is 204
# No content for airport ID 13485, API status code is 204
# No content for airport ID 10781, API status code is 204
# No content for airport ID 10849, API status code is 204
# No content for airport ID 14955, API status code is 204
# No content for airport ID 13433, API status code is 204
# No content for airport ID 15074, API status code is 204
# No content for airport ID 13127, API status code is 204
# No content for airport ID 11013, API status code is 204
# No content for airport ID 14122, API status code is 204
# No content for airport ID 10154, API status code is 204
# No content for airport ID 10980, API status code is 204
# No content for airport ID 14098, API status code is 204
# For airport ID 12982 and year_month : 2019-01 API status code is 200
# For airport ID 12982 and year_month : 2019-02 API status code is 200
# For airport ID 12982 and year_month : 2019-03 API status code is 200
# For airport ID 12982 and year_month : 2019-04 API status code is 200
# For airport ID 12982 and year_month : 2019-05 API status code is 200
# For airport ID 12982 and year_month : 2019-06 API status code is 200
# For airport ID 12982 and year_month : 2019-07 API status code is 200
# For airport ID 12982 and year_month : 2019-08 API status code is 200
# For airport ID 12982 and year_month : 2019-09 API status code is 200
# For airport ID 12982 and year_month : 2019-10 API status code is 200
# For airport ID 12982 and year_month : 2019-11 API status code is 200
# For airport ID 12982 and year_month : 2019-12 API status code is 200
# For airport ID 12982 and year_month : 2020-01 API status code is 200
# For airport ID 12982 and year_month : 2020-02 API status code is 200
# For airport ID 12982 and year_month : 2020-03 API status code is 200
# No content for airport ID 14512, API status code is 204
# No content for airport ID 12278, API status code is 204
# No content for airport ID 15919, API status code is 204
# For airport ID 12478 and year_month : 2019-01 API status code is 200
# For airport ID 12478 and year_month : 2019-02 API status code is 200
# For airport ID 12478 and year_month : 2019-03 API status code is 200
# For airport ID 12478 and year_month : 2019-04 API status code is 200
# For airport ID 12478 and year_month : 2019-05 API status code is 200
# For airport ID 12478 and year_month : 2019-06 API status code is 200
# For airport ID 12478 and year_month : 2019-07 API status code is 200
# For airport ID 12478 and year_month : 2019-08 API status code is 200
# For airport ID 12478 and year_month : 2019-09 API status code is 200
# For airport ID 12478 and year_month : 2019-10 API status code is 200
# For airport ID 12478 and year_month : 2019-11 API status code is 200
# For airport ID 12478 and year_month : 2019-12 API status code is 200
# For airport ID 12478 and year_month : 2020-01 API status code is 200
# For airport ID 12478 and year_month : 2020-02 API status code is 200
# For airport ID 12478 and year_month : 2020-03 API status code is 200
# For airport ID 13830 and year_month : 2019-01 API status code is 200
# For airport ID 13830 and year_month : 2019-02 API status code is 200
# For airport ID 13830 and year_month : 2019-03 API status code is 200
# For airport ID 13830 and year_month : 2019-04 API status code is 200
# For airport ID 13830 and year_month : 2019-05 API status code is 200
# For airport ID 13830 and year_month : 2019-06 API status code is 200
# For airport ID 13830 and year_month : 2019-07 API status code is 200
# For airport ID 13830 and year_month : 2019-08 API status code is 200
# For airport ID 13830 and year_month : 2019-09 API status code is 200
# For airport ID 13830 and year_month : 2019-10 API status code is 200
# For airport ID 13830 and year_month : 2019-11 API status code is 200
# For airport ID 13830 and year_month : 2019-12 API status code is 200
# For airport ID 13830 and year_month : 2020-01 API status code is 200
# For airport ID 13830 and year_month : 2020-02 API status code is 200
# For airport ID 13830 and year_month : 2020-03 API status code is 200
# No content for airport ID 13933, API status code is 204
# For airport ID 13930 and year_month : 2019-01 API status code is 200
# For airport ID 13930 and year_month : 2019-02 API status code is 200
# For airport ID 13930 and year_month : 2019-03 API status code is 200
# For airport ID 13930 and year_month : 2019-04 API status code is 200
# For airport ID 13930 and year_month : 2019-05 API status code is 200
# For airport ID 13930 and year_month : 2019-06 API status code is 200
# For airport ID 13930 and year_month : 2019-07 API status code is 200
# For airport ID 13930 and year_month : 2019-08 API status code is 200
# For airport ID 13930 and year_month : 2019-09 API status code is 200
# For airport ID 13930 and year_month : 2019-10 API status code is 200
# For airport ID 13930 and year_month : 2019-11 API status code is 200
# For airport ID 13930 and year_month : 2019-12 API status code is 200
# For airport ID 13930 and year_month : 2020-01 API status code is 200
# For airport ID 13930 and year_month : 2020-02 API status code is 200
# For airport ID 13930 and year_month : 2020-03 API status code is 200
# No content for airport ID 11997, API status code is 204
# No content for airport ID 11027, API status code is 204
# No content for airport ID 15582, API status code is 204
# No content for airport ID 11721, API status code is 204
# No content for airport ID 12896, API status code is 204
# No content for airport ID 10279, API status code is 204
# No content for airport ID 11778, API status code is 204
# No content for airport ID 12888, API status code is 204
# No content for airport ID 14262, API status code is 204
# No content for airport ID 11415, API status code is 204
# No content for airport ID 10685, API status code is 204
# No content for airport ID 14842, API status code is 204
# No content for airport ID 14761, API status code is 204
# For airport ID 11193 and year_month : 2019-01 API status code is 200
# For airport ID 11193 and year_month : 2019-02 API status code is 200
# For airport ID 11193 and year_month : 2019-03 API status code is 200
# For airport ID 11193 and year_month : 2019-04 API status code is 200
# For airport ID 11193 and year_month : 2019-05 API status code is 200
# For airport ID 11193 and year_month : 2019-06 API status code is 200
# For airport ID 11193 and year_month : 2019-07 API status code is 200
# For airport ID 11193 and year_month : 2019-08 API status code is 200
# For airport ID 11193 and year_month : 2019-09 API status code is 200
# For airport ID 11193 and year_month : 2019-10 API status code is 200
# For airport ID 11193 and year_month : 2019-11 API status code is 200
# For airport ID 11193 and year_month : 2019-12 API status code is 200
# For airport ID 11193 and year_month : 2020-01 API status code is 200
# For airport ID 11193 and year_month : 2020-02 API status code is 200
# For airport ID 11193 and year_month : 2020-03 API status code is 200
# No content for airport ID 12265, API status code is 204
# No content for airport ID 14288, API status code is 204
# No content for airport ID 10713, API status code is 204
# No content for airport ID 12397, API status code is 204
# No content for airport ID 15624, API status code is 204
# No content for airport ID 10994, API status code is 204
# No content for airport ID 10409, API status code is 204
# No content for airport ID 12519, API status code is 204
# No content for airport ID 10136, API status code is 204
# No content for airport ID 15607, API status code is 204
# No content for airport ID 14237, API status code is 204
# No content for airport ID 10779, API status code is 204
# No content for airport ID 11898, API status code is 204
# No content for airport ID 11413, API status code is 204
# No content for airport ID 13983, API status code is 204
# No content for airport ID 10558, API status code is 204
# No content for airport ID 10620, API status code is 204
# No content for airport ID 14222, API status code is 204
# No content for airport ID 13198, API status code is 204
# No content for airport ID 10423, API status code is 204
# No content for airport ID 11097, API status code is 204
# No content for airport ID 15454, API status code is 204
# No content for airport ID 15370, API status code is 204
# No content for airport ID 12899, API status code is 204
# No content for airport ID 10135, API status code is 204
# No content for airport ID 12177, API status code is 204
# For airport ID 13303 and year_month : 2019-01 API status code is 200
# For airport ID 13303 and year_month : 2019-02 API status code is 200
# For airport ID 13303 and year_month : 2019-03 API status code is 200
# For airport ID 13303 and year_month : 2019-04 API status code is 200
# For airport ID 13303 and year_month : 2019-05 API status code is 200
# For airport ID 13303 and year_month : 2019-06 API status code is 200
# For airport ID 13303 and year_month : 2019-07 API status code is 200
# For airport ID 13303 and year_month : 2019-08 API status code is 200
# For airport ID 13303 and year_month : 2019-09 API status code is 200
# For airport ID 13303 and year_month : 2019-10 API status code is 200
# For airport ID 13303 and year_month : 2019-11 API status code is 200
# For airport ID 13303 and year_month : 2019-12 API status code is 200
# For airport ID 13303 and year_month : 2020-01 API status code is 200
# For airport ID 13303 and year_month : 2020-02 API status code is 200
# For airport ID 13303 and year_month : 2020-03 API status code is 200
# No content for airport ID 13795, API status code is 204
# No content for airport ID 10693, API status code is 204
# No content for airport ID 12945, API status code is 204
# No content for airport ID 12511, API status code is 204
# --------------------------------------------------------------------------
# Total processing time: 89 minutes and 46 seconds
# --------------------------------------------------------------------------

# %%
len(all_API_flights_in_list)
# Out:
# 585

# %%
len(all_API_flights_in_list[0])
# Out:
# 10159

# %%
all_API_flights_in_list[0][0] # lista zawiera listy ze słownikami, ponieważ 1 miesiąc z endpointu zwraca dane dla każdego dnia, dlatego trzeba wejść głębiej w strukturę danych.
# Out:
# {'MONTH': 1,
#  'DAY_OF_MONTH': 20,
#  'DAY_OF_WEEK': 7,
#  'OP_UNIQUE_CARRIER': 'WN',
#  'TAIL_NUM': 'N204WN',
#  'OP_CARRIER_FL_NUM': 682,
#  'ORIGIN_AIRPORT_ID': 10397,
#  'DEST_AIRPORT_ID': 11292,
#  'CRS_DEP_TIME': 605,
#  'DEP_TIME': 602,
#  'DEP_DELAY_NEW': 0,
#  'DEP_TIME_BLK': '0600-0659',
#  'CRS_ARR_TIME': 730,
#  'ARR_TIME': 726,
#  'ARR_DELAY_NEW': 0,
#  'ARR_TIME_BLK': '0700-0759',
#  'CANCELLED': 0,
#  'CRS_ELAPSED_TIME': 205,
#  'ACTUAL_ELAPSED_TIME': 204,
#  'DISTANCE': 1199,
#  'DISTANCE_GROUP': 5,
#  'YEAR': 2019}

# %% [markdown]
# Zapisuje dane do ramki `flight_df`: najpierw do listy ramek danych używając metody Pandas `from_records`, następnie za pomocą funkcji `concat` łączę dane do jednej ramki danych.

# %%
df_temp_list = []

for i in range(0, len(all_API_flights_in_list)):
    for j in range(0, len(all_API_flights_in_list[i])):
        df_temp = pd.DataFrame.from_records(all_API_flights_in_list[i][j], index=[0])
        df_temp_list.append(df_temp)

flight_df = pd.concat(df_temp_list, ignore_index=True)

# %%
flight_df.shape
# Out:
# (1386120, 27)

# %%
flight_df.tail()
# Out:
#          ACTUAL_ELAPSED_TIME  ARR_DELAY_NEW  ARR_TIME ARR_TIME_BLK  CANCELLED  \
# 1386115                169.0            0.0    2233.0    2200-2259          0
# 1386116                109.0            0.0    1306.0    1300-1359          0
# 1386117                  NaN            NaN       NaN    2000-2059          1
# 1386118                107.0            0.0    2115.0    2100-2159          0
# 1386119                  NaN            NaN       NaN    1000-1059          1
#
#          CRS_ARR_TIME  CRS_DEP_TIME  CRS_ELAPSED_TIME  DAY_OF_MONTH  \
# 1386115          2259          1956               183            26
# 1386116          1321          1120               121            26
# 1386117          2022          1817               125            26
# 1386118          2140          1937               123            26
# 1386119          1003           700               183            26
#
#          DAY_OF_WEEK  ...  OP_CARRIER_FL_NUM  OP_UNIQUE_CARRIER  \
# 1386115            4  ...               1982                 DL
# 1386116            4  ...               1987                 DL
# 1386117            4  ...               1998                 DL
# 1386118            4  ...               2025                 DL
# 1386119            4  ...               2151                 DL
#
#         ORIGIN_AIRPORT_ID  TAIL_NUM  YEAR  CARRIER_DELAY  LATE_AIRCRAFT_DELAY  \
# 1386115             13303    N350DN  2020            NaN                  NaN
# 1386116             13303    N908DE  2020            NaN                  NaN
# 1386117             13303       NaN  2020            NaN                  NaN
# 1386118             13303    N352NW  2020            NaN                  NaN
# 1386119             13303    N352DN  2020            NaN                  NaN
#
#          NAS_DELAY SECURITY_DELAY  WEATHER_DELAY
# 1386115        NaN            NaN            NaN
# 1386116        NaN            NaN            NaN
# 1386117        NaN            NaN            NaN
# 1386118        NaN            NaN            NaN
# 1386119        NaN            NaN            NaN
#
# [5 rows x 27 columns]

# %%
flight_df.describe()
# Out:
#        ACTUAL_ELAPSED_TIME  ARR_DELAY_NEW      ARR_TIME     CANCELLED  \
# count         1.344638e+06   1.344638e+06  1.346730e+06  1.386120e+06
# mean          1.335066e+02   1.389713e+01  1.454546e+03  2.825369e-02
# std           7.471373e+01   4.467795e+01  5.510973e+02  1.656968e-01
# min           2.500000e+01   0.000000e+00  1.000000e+00  0.000000e+00
# 25%           8.200000e+01   0.000000e+00  1.041000e+03  0.000000e+00
# 50%           1.140000e+02   0.000000e+00  1.459000e+03  0.000000e+00
# 75%           1.590000e+02   7.000000e+00  1.917000e+03  0.000000e+00
# max           5.380000e+02   2.560000e+03  2.400000e+03  1.000000e+00
#
#        CRS_ARR_TIME  CRS_DEP_TIME  CRS_ELAPSED_TIME  DAY_OF_MONTH  \
# count  1.386120e+06  1.386120e+06      1.386120e+06  1.386120e+06
# mean   1.478206e+03  1.334447e+03      1.390266e+02  1.570936e+01
# std    5.296749e+02  4.945813e+02      7.457335e+01  8.747288e+00
# min    1.000000e+00  1.000000e+00      3.200000e+01  1.000000e+00
# 25%    1.055000e+03  9.150000e+02      9.000000e+01  8.000000e+00
# 50%    1.510000e+03  1.329000e+03      1.200000e+02  1.600000e+01
# 75%    1.922000e+03  1.739000e+03      1.630000e+02  2.300000e+01
# max    2.400000e+03  2.359000e+03      7.270000e+02  3.100000e+01
#
#         DAY_OF_WEEK  DEP_DELAY_NEW  ...  DISTANCE_GROUP         MONTH  \
# count  1.386120e+06   1.347711e+06  ...    1.386120e+06  1.386120e+06
# mean   3.903999e+00   1.364892e+01  ...    3.420200e+00  5.673192e+00
# std    1.987461e+00   4.469326e+01  ...    2.388941e+00  3.563204e+00
# min    1.000000e+00   0.000000e+00  ...    1.000000e+00  1.000000e+00
# 25%    2.000000e+00   0.000000e+00  ...    2.000000e+00  2.000000e+00
# 50%    4.000000e+00   0.000000e+00  ...    3.000000e+00  5.000000e+00
# 75%    6.000000e+00   6.000000e+00  ...    4.000000e+00  9.000000e+00
# max    7.000000e+00   2.579000e+03  ...    1.100000e+01  1.200000e+01
#
#        OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID          YEAR  CARRIER_DELAY  \
# count       1.386120e+06       1.386120e+06  1.386120e+06  257318.000000
# mean        1.774918e+03       1.262720e+04  2.019195e+03      18.330004
# std         1.455752e+03       1.484031e+03  3.962006e-01      56.595923
# min         1.000000e+00       1.029900e+04  2.019000e+03       0.000000
# 25%         6.280000e+02       1.129200e+04  2.019000e+03       0.000000
# 50%         1.494000e+03       1.289200e+04  2.019000e+03       0.000000
# 75%         2.380000e+03       1.393000e+04  2.019000e+03      16.000000
# max         7.881000e+03       1.530400e+04  2.020000e+03    2560.000000
#
#        LATE_AIRCRAFT_DELAY      NAS_DELAY  SECURITY_DELAY  WEATHER_DELAY
# count        257318.000000  257318.000000   257318.000000  257318.000000
# mean             25.693189      20.688110        0.074515       2.824019
# std              51.710956      42.651874        3.527666      26.574260
# min               0.000000       0.000000        0.000000       0.000000
# 25%               0.000000       0.000000        0.000000       0.000000
# 50%               0.000000       6.000000        0.000000       0.000000
# 75%              31.000000      24.000000        0.000000       0.000000
# max            1438.000000    1567.000000     1078.000000    1239.000000
#
# [8 rows x 23 columns]

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386120 entries, 0 to 1386119
# Data columns (total 27 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ACTUAL_ELAPSED_TIME  1344638 non-null  float64
#  1   ARR_DELAY_NEW        1344638 non-null  float64
#  2   ARR_TIME             1346730 non-null  float64
#  3   ARR_TIME_BLK         1386120 non-null  object
#  4   CANCELLED            1386120 non-null  int64
#  5   CRS_ARR_TIME         1386120 non-null  int64
#  6   CRS_DEP_TIME         1386120 non-null  int64
#  7   CRS_ELAPSED_TIME     1386120 non-null  int64
#  8   DAY_OF_MONTH         1386120 non-null  int64
#  9   DAY_OF_WEEK          1386120 non-null  int64
#  10  DEP_DELAY_NEW        1347711 non-null  float64
#  11  DEP_TIME             1347712 non-null  float64
#  12  DEP_TIME_BLK         1386120 non-null  object
#  13  DEST_AIRPORT_ID      1386120 non-null  int64
#  14  DISTANCE             1386120 non-null  int64
#  15  DISTANCE_GROUP       1386120 non-null  int64
#  16  MONTH                1386120 non-null  int64
#  17  OP_CARRIER_FL_NUM    1386120 non-null  int64
#  18  OP_UNIQUE_CARRIER    1386120 non-null  object
#  19  ORIGIN_AIRPORT_ID    1386120 non-null  int64
#  20  TAIL_NUM             1375089 non-null  object
#  21  YEAR                 1386120 non-null  int64
#  22  CARRIER_DELAY        257318 non-null   float64
#  23  LATE_AIRCRAFT_DELAY  257318 non-null   float64
#  24  NAS_DELAY            257318 non-null   float64
#  25  SECURITY_DELAY       257318 non-null   float64
#  26  WEATHER_DELAY        257318 non-null   float64
# dtypes: float64(10), int64(13), object(4)
# memory usage: 285.5+ MB

# %% [markdown]
#  ## Sprawdzenie
#  Kod poniżej sprawdza, czy ta część została poprawnie wykonana

# %%
flight_df_expected_shape = (1386120, 27)
assert flight_df_expected_shape == flight_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Zapisuję ramkę `flight_df` do pliku `flight.csv` w katalogu `data\raw`

# %%
flight_df.to_csv(r"..\data\raw\flight.csv")

# %% [markdown]
#  # Podsumowanie
#  W tym notatniku pozyskałam dane które są gotowe do dalszej pracy. W kolejnym notatniku stworzę bazę danych wraz ze strukturą.
